# %%
import numpy as np
import cv2
from copy import deepcopy
import os
from PIL import Image
import matplotlib.pyplot as plt
import math
from num2words import num2words
import random
from tqdm import tqdm
from datetime import timedelta
from srt import Subtitle, compose

# %%
class ObjVar:
    def __init__(self, position, bbox, grids, class_name, area):
        self.position = position
        self.bbox = bbox
        self.grids = grids
        self.class_name = class_name
        self.area = area
        

class ObjDetector(object):
    def __init__(self):
        self.labels_dict = {
            0:  {'name': 'unlabeled',      'color': (0,   0,   0),   'ct_scape_id': 0,  'train_id': 255},
            1:  {'name': 'road',           'color': (128, 64,  128), 'ct_scape_id': 7,  'train_id': 1},
            2:  {'name': 'sidewalk',       'color': (244, 35,  232), 'ct_scape_id': 8,  'train_id': 2},
            3:  {'name': 'building',       'color': (70,  70,  70),  'ct_scape_id': 11, 'train_id': 3},
            4:  {'name': 'wall',           'color': (102, 102, 156), 'ct_scape_id': 12, 'train_id': 4},
            5:  {'name': 'fence',          'color': (190, 153, 153), 'ct_scape_id': 13, 'train_id': 5},
            6:  {'name': 'pole',           'color': (153, 153, 153), 'ct_scape_id': 17, 'train_id': 6},
            7:  {'name': 'traffic light',  'color': (250, 170, 30),  'ct_scape_id': 19, 'train_id': 7},
            8:  {'name': 'traffic sign',   'color': (220, 220, 0),   'ct_scape_id': 20, 'train_id': 8},
            9:  {'name': 'vegetation',     'color': (107, 142, 35),  'ct_scape_id': 21, 'train_id': 9},
            10: {'name': 'terrain',        'color': (152, 251, 152), 'ct_scape_id': 22, 'train_id': 10},
            11: {'name': 'sky',            'color': (70,  130, 180), 'ct_scape_id': 23, 'train_id': 11},
            12: {'name': 'person',         'color': (220, 20,  60),  'ct_scape_id': 24, 'train_id': 12},
            13: {'name': 'rider',          'color': (255, 0,   0),   'ct_scape_id': 25, 'train_id': 13},
            14: {'name': 'car',            'color': (0,   0,   142), 'ct_scape_id': 26, 'train_id': 14},
            15: {'name': 'truck',          'color': (0,   0,   70),  'ct_scape_id': 27, 'train_id': 15},
            16: {'name': 'bus',            'color': (0,   60,  100), 'ct_scape_id': 28, 'train_id': 16},
            17: {'name': 'train',          'color': (0,   80,  100), 'ct_scape_id': 31, 'train_id': 17},
            18: {'name': 'motorcycle',     'color': (0,   0,   230), 'ct_scape_id': 32, 'train_id': 18},
            19: {'name': 'bicycle',        'color': (119, 11,  32),  'ct_scape_id': 33, 'train_id': 19},
            20: {'name': 'dynamic',        'color': (111, 74,  0),   'ct_scape_id': 5,  'train_id': 20},
            21: {'name': 'ground',         'color': (81,  0,   81),  'ct_scape_id': 6,  'train_id': 21},
            22: {'name': 'parking',        'color': (250, 170, 160), 'ct_scape_id': 9,  'train_id': 22},
            23: {'name': 'rail track',     'color': (230, 150, 140), 'ct_scape_id': 10, 'train_id': 23},
            24: {'name': 'guard rail',     'color': (180, 165, 180), 'ct_scape_id': 14, 'train_id': 24},
            25: {'name': 'bridge',         'color': (150, 100, 100), 'ct_scape_id': 15, 'train_id': 25},
            26: {'name': 'tunnel',         'color': (150, 120, 90),  'ct_scape_id': 16, 'train_id': 26},
            27: {'name': 'polegroup',      'color': (153, 153, 153), 'ct_scape_id': 18, 'train_id': 27},
            28: {'name': 'caravan',        'color': (0,   0,   90),  'ct_scape_id': 29, 'train_id': 28},
            29: {'name': 'trailer',        'color': (0,   0,   110), 'ct_scape_id': 30, 'train_id': 29}
        }
        
    def get_grid_span(self, x, y, w, h, h_g_l, v_g_l):
        g_x = []
        g_y = []
        
        i = 1
        while not (x >= h_g_l[i - 1] and x < h_g_l[i]):
            i += 1
        g_x.append(i)

        while not (x+w >= h_g_l[i - 1] and x+w < h_g_l[i]):
            i += 1  
        if not i in g_x:
            g_x.append(i)
        if len(g_x) > 1:
            for ii in range(g_x[0]+1, g_x[1]):
                g_x.append(ii)
                
        g_x.sort()
        
        j = 1
        while not (y >= v_g_l[j - 1] and y < v_g_l[j]):
            j += 1 
        g_y.append(j)

        while not (y+h >= v_g_l[j - 1] and y+h < v_g_l[j]):
            j += 1  
        if not j in g_y:
            g_y.append(j)
        if len(g_y) > 1:
            for jj in range(g_y[0]+1, g_y[1]):
                g_y.append(jj)      
        g_y.sort()
            
        final_g = []
        for x in g_x:
            for y in g_y:
                final_g.append((y-1)*3 + x)
                
        return final_g

    
    def get_localization(self, img_lbl, detect_obj=[], grid_count=3):
        obj_dict = {}
        for key in self.labels_dict.keys():
            obj_id = self.labels_dict[key]['train_id']
            temp_img = deepcopy(img_lbl)
            temp_img[temp_img != obj_id] = 0
            temp_img[temp_img == obj_id] = 255
            
            temp_img = cv2.GaussianBlur(temp_img, (25, 25), 0)
            temp_img = cv2.dilate(temp_img, np.ones((20, 20), np.uint8), iterations=1)
            temp_img = cv2.erode(temp_img, np.ones((10, 10), np.uint8), iterations=1)

            th = int(np.max(temp_img) * 0.15)
            temp_img[temp_img > th] = 255
            temp_img[temp_img <= th] = 0
            
            contours, hierarchy = cv2.findContours(
                temp_img.astype(np.uint8), 
                cv2.RETR_EXTERNAL, 
                cv2.CHAIN_APPROX_SIMPLE
            )
            
            horizontal_grid_lines = [(i) * (img_lbl.shape[1] // 3) for i in range(grid_count + 1)]
            vertical_grid_lines =  [(i) * (img_lbl.shape[0] // 3) for i in range(grid_count + 1)]
            
            horizontal_grid_lines[-1] = horizontal_grid_lines[-1] + 1
            vertical_grid_lines[-1] = vertical_grid_lines[-1] + 1
       
            for cnt in contours:
                area = cv2.contourArea(cnt)
                if area < 500:
                    continue

                x,y,w,h = cv2.boundingRect(cnt)
                
                if x >= img_lbl.shape[1]:
                    x = x - 1
                
                if x+w >= img_lbl.shape[1]:
                    w = w - 1
                
                if y >= img_lbl.shape[0]:
                    y = y - 1
                
                if y+h >= img_lbl.shape[0]:
                    h = h - 1 

                if h>20 and w>20:
                    if key not in obj_dict.keys():
                        obj_dict[key] = []
                        
                    grids = self.get_grid_span(x, y, w, h, horizontal_grid_lines, vertical_grid_lines)
                    if 7 in grids or 8 in grids or 9 in grids:
                        continue
                        
                    cur_obj = ObjVar(
                        position=[(y + (h//2)), (x + (w//2))],
                        bbox=[y, x, y+h, x+w],
                        grids=grids,
                        class_name=self.labels_dict[key]['name'],
                        area=area
                    )
                    
                    obj_dict[key].append(cur_obj)
                    
            if key not in obj_dict.keys():
                obj_dict[key] = []

        return obj_dict

# %%
def box_iou(a, b): 
    w_intersection = np.maximum (0, (np.minimum(a[2], b[2]) - np.maximum(a[0], b[0])))
    h_intersection = np.maximum (0, (np.minimum(a[3], b[3]) - np.maximum(a[1], b[1])))
    s_intersection = w_intersection * h_intersection
    s_a = (a[2] - a[0])*(a[3] - a[1])
    s_b = (b[2] - b[0])*(b[3] - b[1])
  
    return float(s_intersection)/(s_a + s_b - s_intersection)

# %%
img_pth = "/Users/imrankabir/Downloads/video_for_app/gameplay_video_1/"

image_dir = os.path.join(img_pth, 'lbl')

source_images = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if '.png' in img]
source_images.sort()

# %%
ignores = []
movings = [12, 13, 14, 15, 16, 17, 18, 19, 28, 29]
statics = [2, 3, 4, 5, 6, 7, 8 , 9, 22, 23, 24, 25, 26, 27, 0, 10, 11, 20, 21]
dist_th = 50
iou_th = 0.25

description_dictionary = {}
old_obj_dict = None

fps = 28

des_every_sec = 1

for i in tqdm(range(len(source_images))):
    if not i % (fps * des_every_sec) == 0:
        continue
    img = np.asarray(Image.open(source_images[i]))

    obj_detector = ObjDetector()
    new_obj_dict = obj_detector.get_localization(img_lbl=img)
    
    description_dictionary[i] = {}
    
    if old_obj_dict:
        for k in range(30):
            description_dictionary[i][k] = {
                "appear": 0,
                "appear_grids": [],
                "disappear": 0,
                "disappear_grids": [],
                "move": 0,
                "move_from": [],
                "move_from_grids": [],
                "move_to": [],
                "move_to_grids": []
            }
                
            if k in ignores:
                continue
            elif k in movings or k in statics:
                connections = []
                for no, new_obj in enumerate(new_obj_dict[k]):
                    new_pos = new_obj.position
                    new_bbox = new_obj.bbox
                    new_grid = new_obj.grids
                    for oo, old_obj in enumerate(old_obj_dict[k]):
                        old_pos = old_obj.position
                        old_bbox = old_obj.bbox
                        old_grid = old_obj.grids
                        distance = math.dist(new_pos, old_pos)
                        iou = box_iou(new_bbox, old_bbox)
                        if iou > iou_th and distance < dist_th:
                            connections.append(np.array([oo, no])) 
                
                if connections:
                    connections = np.array(connections)
                    for oo in range(len(old_obj_dict[k])):
                        if oo not in connections[:, 0]:
                            description_dictionary[i][k]["disappear"] += 1
                            description_dictionary[i][k]["disappear_grids"].append(
                                old_obj_dict[k][oo].grids
                            ) 
                        else:
                            description_dictionary[i][k]["move"] += 1
                            frm_ind = connections[np.argwhere(connections[:, 0] == oo)[0][0]]
                            description_dictionary[i][k]["move_from"].append(old_obj_dict[k][frm_ind[0]].position)
                            description_dictionary[i][k]["move_to"].append(new_obj_dict[k][frm_ind[1]].position)
                            description_dictionary[i][k]["move_from_grids"].append(old_obj_dict[k][frm_ind[0]].grids)
                            description_dictionary[i][k]["move_to_grids"].append(new_obj_dict[k][frm_ind[1]].grids)

                    for no in range(len(new_obj_dict[k])):
                        if no not in connections[:, 1]:
                            description_dictionary[i][k]["appear"] += 1
                            description_dictionary[i][k]["appear_grids"].append(
                                new_obj_dict[k][no].grids
                            ) 
                            
    else:
        for k in range(30):
            description_dictionary[i][k] = {
                "appear": 0,
                "appear_grids": [],
                "disappear": 0,
                "disappear_grids": [],
                "move": 0,
                "move_from": [],
                "move_from_grids": [],
                "move_to": [],
                "move_to_grids": []
            }
            if k in ignores:
                continue
            for no in range(len(new_obj_dict[k])):
                description_dictionary[i][k]["appear"] += 1
                description_dictionary[i][k]["appear_grids"].append(new_obj_dict[k][no].grids) 

    old_obj_dict = new_obj_dict
                        
description_dictionary
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4867/4867 [00:14<00:00, 324.47it/s]
# {0: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 4,
#    'appear_grids': [[6], [4], [5, 6], [4, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   3: {'appear': 4,
#    'appear_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1, 2]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   4: {'appear': 3,
#    'appear_grids': [[4], [6], [4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   5: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 1,
#    'appear_grids': [[2, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 2,
#    'appear_grids': [[6], [1, 4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 4,
#    'appear_grids': [[2, 5, 3, 6], [1, 4], [3, 6], [1, 4, 2, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   10: {'appear': 6,
#    'appear_grids': [[4], [5, 6], [4, 5], [2], [2], [3]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   11: {'appear': 2,
#    'appear_grids': [[6], [1, 4, 2, 5, 3, 6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   12: {'appear': 4,
#    'appear_grids': [[6], [1, 4], [3], [3]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 2,
#    'appear_grids': [[3, 6], [3]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 7,
#    'appear_grids': [[6], [6], [4], [5], [2, 5], [1, 2], [1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 5,
#    'appear_grids': [[4], [4], [2, 5], [2, 5], [1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  28: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   3: {'appear': 5,
#    'appear_grids': [[5], [1, 4], [1, 4], [1], [1, 2]],
#    'disappear': 1,
#    'disappear_grids': [[1, 4]],
#    'move': 3,
#    'move_from': [[183, 55], [177, 356], [30, 223]],
#    'move_from_grids': [[1, 4], [1, 4, 2, 5], [1, 2]],
#    'move_to': [[192, 53], [179, 397], [30, 223]],
#    'move_to_grids': [[1, 4], [1, 4, 2, 5], [1, 2]]},
#   4: {'appear': 3,
#    'appear_grids': [[4], [2, 5], [2, 5]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 2,
#    'move_from': [[222, 904], [215, 28]],
#    'move_from_grids': [[6], [4]],
#    'move_to': [[223, 905], [220, 50]],
#    'move_to_grids': [[6], [4]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[210, 27]],
#    'move_from_grids': [[4]],
#    'move_to': [[210, 23]],
#    'move_to_grids': [[4]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[187, 368]],
#    'move_from_grids': [[2, 5]],
#    'move_to': [[195, 373]],
#    'move_to_grids': [[2, 5]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 4,
#    'move_from': [[163, 659], [125, 117], [113, 882], [112, 381]],
#    'move_from_grids': [[2, 5, 3, 6], [1, 4], [3, 6], [1, 4, 2, 5]],
#    'move_to': [[160, 675], [117, 115], [113, 899], [113, 383]],
#    'move_to_grids': [[2, 5, 3, 6], [1, 4], [3, 6], [1, 4, 2, 5]]},
#   10: {'appear': 2,
#    'appear_grids': [[6], [6]],
#    'disappear': 2,
#    'disappear_grids': [[4], [5, 6]],
#    'move': 4,
#    'move_from': [[277, 220], [159, 635], [164, 429], [147, 759]],
#    'move_from_grids': [[4, 5], [2], [2], [3]],
#    'move_to': [[291, 224], [160, 635], [159, 426], [150, 758]],
#    'move_to_grids': [[4, 5], [2], [2], [2, 3]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 1,
#    'move_from': [[111, 496]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[110, 497]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 1,
#    'appear_grids': [[1]],
#    'disappear': 4,
#    'disappear_grids': [[4], [5], [2, 5], [1]],
#    'move': 3,
#    'move_from': [[226, 935], [224, 831], [133, 348]],
#    'move_from_grids': [[6], [6], [1, 2]],
#    'move_to': [[226, 935], [223, 835], [128, 355]],
#    'move_to_grids': [[6], [6], [1, 2]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[223, 209]],
#    'move_from_grids': [[4]],
#    'move_to': [[217, 232]],
#    'move_to_grids': [[4]]},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 1,
#    'appear_grids': [[2]],
#    'disappear': 2,
#    'disappear_grids': [[4], [1]],
#    'move': 3,
#    'move_from': [[217, 80], [197, 436], [206, 367]],
#    'move_from_grids': [[4], [2, 5], [2, 5]],
#    'move_to': [[180, 77], [194, 447], [206, 366]],
#    'move_to_grids': [[1, 4], [2, 5], [2, 5]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  56: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   3: {'appear': 1,
#    'appear_grids': [[2, 5, 3, 6]],
#    'disappear': 2,
#    'disappear_grids': [[5], [1, 4]],
#    'move': 6,
#    'move_from': [[203, 200],
#     [192, 53],
#     [179, 397],
#     [148, 239],
#     [103, 346],
#     [30, 223]],
#    'move_from_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1], [1, 2], [1, 2]],
#    'move_to': [[201, 176],
#     [198, 53],
#     [180, 386],
#     [147, 239],
#     [103, 346],
#     [30, 223]],
#    'move_to_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1], [1, 2], [1, 2]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 2,
#    'disappear_grids': [[2, 5], [2, 5]],
#    'move': 3,
#    'move_from': [[223, 905], [226, 218], [220, 50]],
#    'move_from_grids': [[6], [4], [4]],
#    'move_to': [[223, 909], [226, 213], [224, 70]],
#    'move_to_grids': [[6], [4], [4]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 4,
#    'move_from': [[160, 675], [113, 899], [113, 383], [117, 115]],
#    'move_from_grids': [[2, 5, 3, 6], [3, 6], [1, 4, 2, 5], [1, 4]],
#    'move_to': [[145, 666], [113, 898], [111, 381], [117, 121]],
#    'move_to_grids': [[2, 5, 3, 6], [3, 6], [1, 4, 2, 5], [1, 4]]},
#   10: {'appear': 1,
#    'appear_grids': [[4, 5]],
#    'disappear': 1,
#    'disappear_grids': [[4, 5]],
#    'move': 5,
#    'move_from': [[246, 765], [220, 915], [160, 635], [159, 426], [150, 758]],
#    'move_from_grids': [[6], [6], [2], [2], [2, 3]],
#    'move_to': [[235, 747], [221, 919], [161, 637], [161, 429], [150, 759]],
#    'move_to_grids': [[5, 6], [6], [2], [2], [2, 3]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[110, 497]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[111, 497]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 4,
#    'move_from': [[226, 935], [223, 835], [128, 355], [39, 170]],
#    'move_from_grids': [[6], [6], [1, 2], [1]],
#    'move_to': [[224, 935], [216, 844], [145, 354], [38, 164]],
#    'move_to_grids': [[6], [3, 6], [1, 2], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 1,
#    'appear_grids': [[1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 4,
#    'move_from': [[194, 447], [206, 366], [180, 77], [72, 445]],
#    'move_from_grids': [[2, 5], [2, 5], [1, 4], [2]],
#    'move_to': [[192, 444], [203, 367], [213, 81], [73, 444]],
#    'move_to_grids': [[2, 5], [2, 5], [4], [2]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  84: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   3: {'appear': 4,
#    'appear_grids': [[6], [1, 4], [2, 5], [2, 3]],
#    'disappear': 1,
#    'disappear_grids': [[2, 5, 3, 6]],
#    'move': 6,
#    'move_from': [[201, 176],
#     [198, 53],
#     [180, 386],
#     [147, 239],
#     [103, 346],
#     [30, 223]],
#    'move_from_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1], [1, 2], [1, 2]],
#    'move_to': [[204, 201],
#     [200, 54],
#     [180, 373],
#     [148, 238],
#     [105, 347],
#     [30, 224]],
#    'move_to_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1], [1, 2], [1, 2]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[223, 909], [226, 213], [224, 70]],
#    'move_from_grids': [[6], [4], [4]],
#    'move_to': [[223, 908], [226, 210], [235, 75]],
#    'move_to_grids': [[6], [4], [4]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[185, 388]],
#    'move_from_grids': [[2, 5]],
#    'move_to': [[185, 393]],
#    'move_to_grids': [[2, 5]]},
#   9: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 4,
#    'move_from': [[145, 666], [113, 898], [111, 381], [117, 121]],
#    'move_from_grids': [[2, 5, 3, 6], [3, 6], [1, 4, 2, 5], [1, 4]],
#    'move_to': [[145, 667], [114, 899], [111, 382], [118, 115]],
#    'move_to_grids': [[2, 5, 3, 6], [3, 6], [1, 4, 2, 5], [1, 4]]},
#   10: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 6,
#    'move_from': [[235, 747],
#     [221, 919],
#     [223, 305],
#     [161, 637],
#     [161, 429],
#     [150, 759]],
#    'move_from_grids': [[5, 6], [6], [4, 5], [2], [2], [2, 3]],
#    'move_to': [[222, 725],
#     [221, 915],
#     [221, 312],
#     [161, 637],
#     [159, 429],
#     [151, 753]],
#    'move_to_grids': [[5, 6], [6], [4, 5], [2], [2], [2, 3]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[111, 497]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[110, 497]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 6,
#    'appear_grids': [[5], [6], [5], [4], [5], [3, 6]],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 4,
#    'move_from': [[224, 935], [216, 844], [145, 354], [38, 164]],
#    'move_from_grids': [[6], [3, 6], [1, 2], [1]],
#    'move_to': [[223, 935], [221, 847], [138, 356], [39, 171]],
#    'move_to_grids': [[6], [6], [1, 2], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 3,
#    'appear_grids': [[6], [1], [1, 4]],
#    'disappear': 3,
#    'disappear_grids': [[4], [2, 5], [1]],
#    'move': 2,
#    'move_from': [[203, 367], [73, 444]],
#    'move_from_grids': [[2, 5], [2]],
#    'move_to': [[206, 400], [72, 444]],
#    'move_to_grids': [[2, 5], [2]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  112: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[276, 812]],
#    'move_from_grids': [[5, 6]],
#    'move_to': [[275, 800]],
#    'move_to_grids': [[5, 6]]},
#   3: {'appear': 2,
#    'appear_grids': [[5], [5]],
#    'disappear': 1,
#    'disappear_grids': [[2, 5]],
#    'move': 9,
#    'move_from': [[279, 832],
#     [204, 201],
#     [193, 136],
#     [200, 54],
#     [180, 373],
#     [148, 238],
#     [105, 347],
#     [51, 752],
#     [30, 224]],
#    'move_from_grids': [[6],
#     [1, 4],
#     [1, 4],
#     [1, 4],
#     [1, 4, 2, 5],
#     [1],
#     [1, 2],
#     [2, 3],
#     [1, 2]],
#    'move_to': [[279, 849],
#     [204, 200],
#     [194, 136],
#     [192, 53],
#     [180, 364],
#     [148, 237],
#     [104, 347],
#     [52, 754],
#     [30, 223]],
#    'move_to_grids': [[6],
#     [1, 4],
#     [1, 4],
#     [1, 4],
#     [1, 4, 2, 5],
#     [1],
#     [1, 2],
#     [2, 3],
#     [1, 2]]},
#   4: {'appear': 2,
#    'appear_grids': [[5], [4]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 2,
#    'move_from': [[223, 908], [226, 210]],
#    'move_from_grids': [[6], [4]],
#    'move_to': [[224, 906], [226, 189]],
#    'move_to_grids': [[6], [4]]},
#   5: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[236, 924]],
#    'move_from_grids': [[6]],
#    'move_to': [[239, 924]],
#    'move_to_grids': [[6]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 2,
#    'appear_grids': [[5], [1, 4, 2, 5]],
#    'disappear': 2,
#    'disappear_grids': [[5], [1, 4, 2, 5]],
#    'move': 3,
#    'move_from': [[145, 667], [114, 899], [118, 115]],
#    'move_from_grids': [[2, 5, 3, 6], [3, 6], [1, 4]],
#    'move_to': [[145, 666], [114, 898], [118, 115]],
#    'move_to_grids': [[2, 5, 3, 6], [3, 6], [1, 4]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 7,
#    'move_from': [[295, 76],
#     [221, 915],
#     [222, 725],
#     [221, 312],
#     [161, 637],
#     [159, 429],
#     [151, 753]],
#    'move_from_grids': [[4], [6], [5, 6], [4, 5], [2], [2], [2, 3]],
#    'move_to': [[298, 76],
#     [221, 888],
#     [221, 722],
#     [222, 306],
#     [161, 637],
#     [160, 430],
#     [150, 757]],
#    'move_to_grids': [[4], [6], [5, 6], [4, 5], [2], [2], [2, 3]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[110, 497]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[110, 497]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 1,
#    'move_from': [[231, 874]],
#    'move_from_grids': [[6]],
#    'move_to': [[223, 873]],
#    'move_to_grids': [[6]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 9,
#    'move_from': [[337, 632],
#     [331, 963],
#     [239, 24],
#     [223, 935],
#     [221, 847],
#     [249, 612],
#     [138, 356],
#     [143, 994],
#     [39, 171]],
#    'move_from_grids': [[5], [6], [4], [6], [6], [5], [1, 2], [3, 6], [1]],
#    'move_to': [[346, 627],
#     [330, 961],
#     [225, 40],
#     [223, 935],
#     [221, 847],
#     [251, 584],
#     [147, 353],
#     [148, 993],
#     [43, 175]],
#    'move_to_grids': [[5], [6], [4], [6], [6], [5], [1, 2], [3, 6], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[217, 234]],
#    'move_from_grids': [[4]],
#    'move_to': [[217, 238]],
#    'move_to_grids': [[4]]},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 1,
#    'appear_grids': [[2, 5]],
#    'disappear': 1,
#    'disappear_grids': [[1]],
#    'move': 4,
#    'move_from': [[229, 866], [206, 400], [180, 77], [72, 444]],
#    'move_from_grids': [[6], [2, 5], [1, 4], [2]],
#    'move_to': [[235, 866], [205, 366], [176, 77], [73, 442]],
#    'move_to_grids': [[6], [2, 5], [1, 4], [2]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  140: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[275, 800]],
#    'move_from_grids': [[5, 6]],
#    'move_to': [[276, 797]],
#    'move_to_grids': [[5, 6]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 11,
#    'move_from': [[341, 666],
#     [279, 849],
#     [260, 513],
#     [204, 200],
#     [194, 136],
#     [192, 53],
#     [180, 364],
#     [148, 237],
#     [104, 347],
#     [52, 754],
#     [30, 223]],
#    'move_from_grids': [[5],
#     [6],
#     [5],
#     [1, 4],
#     [1, 4],
#     [1, 4],
#     [1, 4, 2, 5],
#     [1],
#     [1, 2],
#     [2, 3],
#     [1, 2]],
#    'move_to': [[345, 666],
#     [282, 846],
#     [271, 508],
#     [204, 199],
#     [195, 136],
#     [197, 45],
#     [180, 363],
#     [148, 240],
#     [103, 347],
#     [54, 753],
#     [30, 224]],
#    'move_to_grids': [[5, 6],
#     [6],
#     [5],
#     [1, 4],
#     [1, 4],
#     [1, 4],
#     [1, 4, 2, 5],
#     [1],
#     [1, 2],
#     [2, 3],
#     [1, 2]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 3,
#    'move_from': [[224, 906], [226, 189], [215, 27]],
#    'move_from_grids': [[6], [4], [4]],
#    'move_to': [[224, 907], [225, 211], [214, 35]],
#    'move_to_grids': [[6], [4], [4]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[239, 924], [210, 22]],
#    'move_from_grids': [[6], [4]],
#    'move_to': [[237, 926], [210, 26]],
#    'move_to_grids': [[6], [4]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 2,
#    'appear_grids': [[5], [1, 4, 2, 5]],
#    'disappear': 1,
#    'disappear_grids': [[1, 4, 2, 5]],
#    'move': 4,
#    'move_from': [[289, 635], [145, 666], [114, 898], [118, 115]],
#    'move_from_grids': [[5], [2, 5, 3, 6], [3, 6], [1, 4]],
#    'move_to': [[277, 645], [146, 665], [114, 898], [118, 121]],
#    'move_to_grids': [[5], [2, 5, 3, 6], [3, 6], [1, 4]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 2,
#    'disappear_grids': [[4], [4, 5]],
#    'move': 5,
#    'move_from': [[221, 888], [221, 722], [161, 637], [160, 430], [150, 757]],
#    'move_from_grids': [[6], [5, 6], [2], [2], [2, 3]],
#    'move_to': [[221, 887], [228, 722], [161, 637], [159, 429], [151, 756]],
#    'move_to_grids': [[6], [5, 6], [2], [2], [2, 3]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[110, 497]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[110, 497]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[223, 873]],
#    'move_from_grids': [[6]],
#    'move_to': [[221, 873]],
#    'move_to_grids': [[6]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 2,
#    'appear_grids': [[5], [5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[281, 606], [206, 628]],
#    'move_from_grids': [[5], [2, 5]],
#    'move_to': [[284, 611], [214, 629]],
#    'move_to_grids': [[5], [2, 5]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 3,
#    'appear_grids': [[5], [5], [4]],
#    'disappear': 3,
#    'disappear_grids': [[5], [4], [5]],
#    'move': 6,
#    'move_from': [[330, 961],
#     [223, 935],
#     [221, 847],
#     [147, 353],
#     [148, 993],
#     [43, 175]],
#    'move_from_grids': [[6], [6], [6], [1, 2], [3, 6], [1]],
#    'move_to': [[331, 961],
#     [224, 935],
#     [221, 845],
#     [146, 354],
#     [146, 994],
#     [41, 171]],
#    'move_to_grids': [[6], [6], [6], [1, 2], [3, 6], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[240, 171]],
#    'move_from_grids': [[4]],
#    'move_to': [[241, 164]],
#    'move_to_grids': [[4]]},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 1,
#    'appear_grids': [[1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 5,
#    'move_from': [[235, 866], [195, 436], [205, 366], [176, 77], [73, 442]],
#    'move_from_grids': [[6], [2, 5], [2, 5], [1, 4], [2]],
#    'move_to': [[233, 869], [194, 435], [200, 367], [178, 78], [72, 444]],
#    'move_to_grids': [[6], [2, 5], [2, 5], [1, 4], [2]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  168: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   3: {'appear': 3,
#    'appear_grids': [[6], [2, 5], [2]],
#    'disappear': 7,
#    'disappear_grids': [[5, 6], [6], [5], [1, 4], [1], [1, 2], [2, 3]],
#    'move': 4,
#    'move_from': [[204, 199], [197, 45], [180, 363], [30, 224]],
#    'move_from_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1, 2]],
#    'move_to': [[189, 183], [169, 62], [174, 393], [30, 262]],
#    'move_to_grids': [[1, 4], [1, 4], [1, 4, 2, 5], [1, 2]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 2,
#    'appear_grids': [[3, 6], [1, 4]],
#    'disappear': 4,
#    'disappear_grids': [[5], [5], [3, 6], [1, 4]],
#    'move': 2,
#    'move_from': [[146, 665], [114, 382]],
#    'move_from_grids': [[2, 5, 3, 6], [1, 4, 2, 5]],
#    'move_to': [[115, 668], [141, 418]],
#    'move_to_grids': [[2, 5, 3, 6], [1, 4, 2, 5]]},
#   10: {'appear': 6,
#    'appear_grids': [[4], [4], [4, 5], [3], [2], [3]],
#    'disappear': 4,
#    'disappear_grids': [[6], [2], [2], [2, 3]],
#    'move': 1,
#    'move_from': [[228, 722]],
#    'move_from_grids': [[5, 6]],
#    'move_to': [[213, 756]],
#    'move_to_grids': [[2, 5, 3, 6]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[110, 497]],
#    'move_from_grids': [[1, 4, 2, 5, 3, 6]],
#    'move_to': [[107, 501]],
#    'move_to_grids': [[1, 4, 2, 5, 3, 6]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[232, 98]],
#    'move_from_grids': [[4]],
#    'move_to': [[234, 84]],
#    'move_to_grids': [[4]]},
#   15: {'appear': 3,
#    'appear_grids': [[4], [3, 6], [1]],
#    'disappear': 3,
#    'disappear_grids': [[5], [5], [2, 5]],
#    'move': 1,
#    'move_from': [[350, 538]],
#    'move_from_grids': [[5]],
#    'move_to': [[355, 546]],
#    'move_to_grids': [[5]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 6,
#    'appear_grids': [[4], [4], [5], [4, 5], [2], [1]],
#    'disappear': 8,
#    'disappear_grids': [[5], [6], [6], [5], [4], [1, 2], [3, 6], [1]],
#    'move': 1,
#    'move_from': [[331, 961]],
#    'move_from_grids': [[6]],
#    'move_to': [[329, 955]],
#    'move_to_grids': [[6]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 3,
#    'appear_grids': [[1, 4], [1, 4, 2, 5], [2]],
#    'disappear': 5,
#    'disappear_grids': [[6], [2, 5], [1], [1, 4], [2]],
#    'move': 1,
#    'move_from': [[194, 435]],
#    'move_from_grids': [[2, 5]],
#    'move_to': [[201, 439]],
#    'move_to_grids': [[2, 5]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
# ...
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 3,
#    'appear_grids': [[2, 5, 3, 6], [3], [1]],
#    'disappear': 4,
#    'disappear_grids': [[6], [2], [1], [3]],
#    'move': 1,
#    'move_from': [[168, 418]],
#    'move_from_grids': [[2, 5]],
#    'move_to': [[140, 419]],
#    'move_to_grids': [[2]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  4816: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 1,
#    'appear_grids': [[1, 2]],
#    'disappear': 2,
#    'disappear_grids': [[1, 2], [2]],
#    'move': 1,
#    'move_from': [[51, 313]],
#    'move_from_grids': [[1, 2]],
#    'move_to': [[42, 317]],
#    'move_to_grids': [[1, 2]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 3,
#    'disappear_grids': [[5], [2], [3]],
#    'move': 2,
#    'move_from': [[211, 737], [203, 557]],
#    'move_from_grids': [[3, 6], [2, 5]],
#    'move_to': [[213, 735], [194, 554]],
#    'move_to_grids': [[3, 6], [2, 5]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[49, 447]],
#    'move_from_grids': [[2]],
#    'move_to': [[47, 454]],
#    'move_to_grids': [[2]]},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[58, 802]],
#    'move_from_grids': [[3]],
#    'move_to': [[58, 802]],
#    'move_to_grids': [[3]]},
#   12: {'appear': 1,
#    'appear_grids': [[3, 6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[313, 391]],
#    'move_from_grids': [[4, 5]],
#    'move_to': [[311, 395]],
#    'move_to_grids': [[4, 5]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[225, 482]],
#    'move_from_grids': [[5]],
#    'move_to': [[216, 482]],
#    'move_to_grids': [[5]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[42, 216], [40, 160]],
#    'move_from_grids': [[1], [1]],
#    'move_to': [[40, 186], [40, 186]],
#    'move_to_grids': [[1], [1]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 1,
#    'appear_grids': [[2]],
#    'disappear': 1,
#    'disappear_grids': [[2, 5, 3, 6]],
#    'move': 3,
#    'move_from': [[140, 419], [94, 783], [32, 28]],
#    'move_from_grids': [[2], [3], [1]],
#    'move_to': [[141, 418], [90, 793], [30, 27]],
#    'move_to_grids': [[2], [3], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}},
#  4844: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[140, 402], [42, 317]],
#    'move_from_grids': [[1, 2], [1, 2]],
#    'move_to': [[141, 400], [42, 317]],
#    'move_to_grids': [[1, 2], [1, 2]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[213, 735], [194, 554]],
#    'move_from_grids': [[3, 6], [2, 5]],
#    'move_to': [[209, 735], [198, 550]],
#    'move_to_grids': [[3, 6], [2, 5]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[47, 454]],
#    'move_from_grids': [[2]],
#    'move_to': [[47, 454]],
#    'move_to_grids': [[2]]},
#   11: {'appear': 1,
#    'appear_grids': [[3]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[58, 802]],
#    'move_from_grids': [[3]],
#    'move_to': [[58, 802]],
#    'move_to_grids': [[3]]},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[311, 395], [208, 737]],
#    'move_from_grids': [[4, 5], [3, 6]],
#    'move_to': [[311, 405], [209, 740]],
#    'move_to_grids': [[4, 5], [3, 6]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[216, 482]],
#    'move_from_grids': [[5]],
#    'move_to': [[216, 481]],
#    'move_to_grids': [[5]]},
#   16: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[40, 186]],
#    'move_from_grids': [[1]],
#    'move_to': [[41, 217]],
#    'move_to_grids': [[1]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   20: {'appear': 2,
#    'appear_grids': [[2, 5], [2, 5]],
#    'disappear': 1,
#    'disappear_grids': [[2]],
#    'move': 3,
#    'move_from': [[141, 418], [90, 793], [30, 27]],
#    'move_from_grids': [[2], [3], [1]],
#    'move_to': [[140, 419], [90, 792], [31, 27]],
#    'move_to_grids': [[2], [3], [1]]},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_from_grids': [],
#    'move_to': [],
#    'move_to_grids': []}}}

# %%
background_class = [9, 11]  # done
side_walk = [2]  # done
side_walk_object_beside = [4, 5, 10]  # done
side_walk_object_over = [6, 27]  # done
road = [1]
road_moving_object = [13, 14, 15, 16, 17, 18, 19, 28, 29, 13]  # done
road_over_object = [7, 8]  # done
human = [12]  # done
ignore = [0]  # done
construction = [3, 23, 24, 25, 26] # done
parking = [22]
dynamic = [20]


descriptions = {}
pos_dict = {
    1: "far left",
    2: "far center",
    3: "far right",
    4: "left",
    5: "center",
    6: "right"
}

appear_syn_sing = ['becomes visible', 'comes into view', 'appears']
appear_syn_plu = ['become visible', 'come into view', 'appear']

disappear_syn_plu = ["vanish", "pass from sight", "vanish from sight", 
                      "recede from view", "are lost to sight"]

disappear_syn_sing = ["vanishes", "passes from sight", "vanishes from sight", 
                      "recedes from view", "is lost to sight"]


bg_described = False

labels_dicto = ObjDetector().labels_dict
for key in tqdm(description_dictionary.keys()):
    descriptions[key] = []
    for key2 in description_dictionary[key].keys():
        appear_count = description_dictionary[key][key2]["appear"]
        disappear_count = description_dictionary[key][key2]["disappear"]
        move_count = description_dictionary[key][key2]["move"]
        
        if key2 in background_class:
            if not bg_described:
                bg_obj_names = []
                for bg_obj in background_class:
                    if description_dictionary[key][bg_obj]['appear'] > 0:
                        bg_obj_names.append(labels_dicto[bg_obj]['name'])
                if 'sky' in bg_obj_names and 'vegetation' in bg_obj_names:  
                    descriptions[key].append(
                        "There are sky and bunch of trees in the horizon"
                    )
                elif 'sky' in bg_obj_names and 'vegetation' not in bg_obj_names:  
                    descriptions[key].append(
                        "There is sky in the horizon"
                    )
                else:
                    descriptions[key].append(
                        "There are sky and bunch of trees in the horizon"
                    )
                bg_described = True
            else:
                bg_obj_names = []
                for bg_obj in background_class:
                    if description_dictionary[key][bg_obj]['appear'] > 0:
                        bg_obj_names.append(labels_dicto[bg_obj]['name'])
                if len(bg_obj_names) == 0:
                    bg_described = False
            continue
            
        if appear_count > 0:
            add_s = ''
            if appear_count > 1:
                add_s = 's'
                
            if key2 in ignore:
                continue      
            elif key2 in side_walk or key2 in construction or key2 in human:
                all_appear_grids = []

                for grd in description_dictionary[key][key2]["appear_grids"]:
                    all_appear_grids += grd

                unique_appear_grid = list(set(all_appear_grids))
                pos_s = ''

                if len(unique_appear_grid) >= 5:
                    pos_s = f"At your both side there are {labels_dicto[key2]['name']}s"
                elif len(unique_appear_grid) == 1:
                    rand_ind = random.randint(0, len(appear_syn_sing)-1)
                    pos_s = f"A {labels_dicto[key2]['name']} {appear_syn_sing[rand_ind]} at the {pos_dict[unique_appear_grid[0]]}"
                elif len(unique_appear_grid) == 2:
                    pos_s = f"On your {pos_dict[unique_appear_grid[0]]} and {pos_dict[unique_appear_grid[1]]} side there are {labels_dicto[key2]['name']}s"
                elif len(unique_appear_grid) == 3 or len(unique_appear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_appear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s far"
                    elif close_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s near"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_appear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_appear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are ahead of you"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is ahead of you"
                        else:
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are at your {max_pos_n}"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is at your {max_pos_n}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )

            elif key2 in road_moving_object or key2 in road_over_object:  
                all_appear_grids = []

                for grd in description_dictionary[key][key2]["appear_grids"]:
                    all_appear_grids += grd

                unique_appear_grid = list(set(all_appear_grids))
                pos_s = ''

                if key2 in road_moving_object:
                    st_str = "On"
                else:
                    st_str = "Over"

                if len(unique_appear_grid) >= 5:
                    pos_s = f"{st_str} the road there are {labels_dicto[key2]['name']}s at your both side"
                elif len(unique_appear_grid) == 1:
                    rand_ind = random.randint(0, len(appear_syn_sing)-1)
                    pos_s = f"{st_str} the road a {labels_dicto[key2]['name']} {appear_syn_sing[rand_ind]} at the {pos_dict[unique_appear_grid[0]]}"
                elif len(unique_appear_grid) == 2:
                    pos_s = f"{st_str} your {pos_dict[unique_appear_grid[0]]} and {pos_dict[unique_appear_grid[1]]} side there are {labels_dicto[key2]['name']}s on the road"
                elif len(unique_appear_grid) == 3 or len(unique_appear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_appear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s far in front of you"
                    elif close_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s near in front of you"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_appear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_appear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are ahead of you"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is ahead of you"
                        else:
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are at your {max_pos_n}"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is at your {max_pos_n}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )

            elif key2 in side_walk_object_beside or key2 in side_walk_object_over:         
                all_appear_grids = []

                for grd in description_dictionary[key][key2]["appear_grids"]:
                    all_appear_grids += grd

                unique_appear_grid = list(set(all_appear_grids))
                pos_s = ''

                if key2 in side_walk_object_beside:
                    st_str = "Beside"
                else:
                    st_str = "Over"

                if len(unique_appear_grid) >= 5:
                    pos_s = f"{st_str} the sidewalk there are {labels_dicto[key2]['name']}s at your both side"
                elif len(unique_appear_grid) == 1:
                    rand_ind = random.randint(0, len(appear_syn_sing)-1)
                    pos_s = f"{st_str} the {pos_dict[unique_appear_grid[0]]} sidewalk a {labels_dicto[key2]['name']} {appear_syn_sing[rand_ind]}"
                elif len(unique_appear_grid) == 2:
                    pos_s = f"{st_str} the {pos_dict[unique_appear_grid[0]]} and {pos_dict[unique_appear_grid[1]]} sidewalk there are {labels_dicto[key2]['name']}s"
                elif len(unique_appear_grid) == 3 or len(unique_appear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_appear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s far in front of you"
                    elif close_count == 3:
                        pos_s = f"There are some {labels_dicto[key2]['name']}s near in front of you"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_appear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_appear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are ahead of you"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is ahead of you"
                        else:
                            if appear_count > 1:
                                pos_s = f"A few {labels_dicto[key2]['name']}s are at your {max_pos_n}"
                            else:
                                pos_s = f"A {labels_dicto[key2]['name']} is at your {max_pos_n}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )
                    
        if disappear_count > 0:
            add_s = ''
            ws_wwr = 'was'
            if disappear_count > 1:
                add_s = 's'
                ws_wwr = 'were'
                
            if key2 in ignore:
                continue      
            elif key2 in side_walk or key2 in construction or key2 in human:
                all_disappear_grids = []

                for grd in description_dictionary[key][key2]["disappear_grids"]:
                    all_disappear_grids += grd

                unique_disappear_grid = list(set(all_disappear_grids))
                pos_s = ''

                if len(unique_disappear_grid) >= 5:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"From your both side {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                elif len(unique_disappear_grid) == 1:
                    rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                    pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from the {pos_dict[unique_disappear_grid[0]]}"
                elif len(unique_disappear_grid) == 2:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from your {pos_dict[unique_disappear_grid[0]]} and {pos_dict[unique_disappear_grid[1]]}"
                elif len(unique_disappear_grid) == 3 or len(unique_disappear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_disappear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From the far front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    elif close_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From near front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_disappear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_disappear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from ahead of you"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from ahead of you"
                        else:
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"Few {labels_dicto[key2]['name']}s from your {max_pos_n} {disappear_syn_plu[rand_ind]}"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"The {labels_dicto[key2]['name']} which was at your {max_pos_n} {disappear_syn_sing[rand_ind]}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )
                    
                    
            elif key2 in road_moving_object or key2 in road_over_object:  
                all_disappear_grids = []

                for grd in description_dictionary[key][key2]["disappear_grids"]:
                    all_disappear_grids += grd

                unique_disappear_grid = list(set(all_disappear_grids))
                pos_s = ''
                
                if key2 in road_moving_object:
                    st_str = "On"
                else:
                    st_str = "Over"
                
                if len(unique_disappear_grid) >= 5:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"From your both side {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                elif len(unique_disappear_grid) == 1:
                    rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                    pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from the {pos_dict[unique_disappear_grid[0]]}"
                elif len(unique_disappear_grid) == 2:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from your {pos_dict[unique_disappear_grid[0]]} and {pos_dict[unique_disappear_grid[1]]}"
                elif len(unique_disappear_grid) == 3 or len(unique_disappear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_disappear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From the far front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    elif close_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From near front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_disappear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_disappear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from ahead of you"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from ahead of you"
                        else:
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"Few {labels_dicto[key2]['name']}s from your {max_pos_n} {disappear_syn_plu[rand_ind]}"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"The {labels_dicto[key2]['name']} which was at your {max_pos_n} {disappear_syn_sing[rand_ind]}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )
                    
            elif key2 in side_walk_object_beside or key2 in side_walk_object_over: 
                all_disappear_grids = []

                for grd in description_dictionary[key][key2]["disappear_grids"]:
                    all_disappear_grids += grd

                unique_disappear_grid = list(set(all_disappear_grids))
                pos_s = ''
                
                if key2 in road_moving_object:
                    st_str = "Beside"
                else:
                    st_str = "Over"
                
                if len(unique_disappear_grid) >= 5:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"From your both side {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                elif len(unique_disappear_grid) == 1:
                    rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                    pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from the {pos_dict[unique_disappear_grid[0]]}"
                elif len(unique_disappear_grid) == 2:
                    rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                    pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from your {pos_dict[unique_disappear_grid[0]]} and {pos_dict[unique_disappear_grid[1]]}"
                elif len(unique_disappear_grid) == 3 or len(unique_disappear_grid) == 4:
                    far_count = 0
                    close_count = 0
                    for bb in range(3):
                        if "far" in pos_dict[unique_disappear_grid[bb]]:
                            far_count += 1
                        else:
                            close_count += 1
                    if far_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From the far front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    elif close_count == 3:
                        rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                        pos_s = f"From near front some {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]}"
                    else:
                        left_count = 0
                        right_count = 0
                        center_count = 0
                        for bb in range(3):
                            if "left" in pos_dict[unique_disappear_grid[bb]]:
                                left_count += 1
                            elif "right" in pos_dict[unique_disappear_grid[bb]]:
                                right_count += 1
                            else:
                                center_count += 1
                        pos_array = ['left', 'center', 'right']
                        pos_ind_ar = [left_count, center_count, right_count]
                        max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                        max_pos_n = pos_array[max_pos_ind]
                        if max_pos_n == 'center':
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"A few {labels_dicto[key2]['name']}s {disappear_syn_plu[rand_ind]} from ahead of you"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"A {labels_dicto[key2]['name']} {disappear_syn_sing[rand_ind]} from ahead of you"
                        else:
                            if disappear_count > 1:
                                rand_ind = random.randint(0, len(disappear_syn_plu)-1)
                                pos_s = f"Few {labels_dicto[key2]['name']}s from your {max_pos_n} {disappear_syn_plu[rand_ind]}"
                            else:
                                rand_ind = random.randint(0, len(disappear_syn_sing)-1)
                                pos_s = f"The {labels_dicto[key2]['name']} which was at your {max_pos_n} {disappear_syn_sing[rand_ind]}"
                if pos_s:
                    descriptions[key].append(
                        pos_s
                    )
                    
        if move_count > 0:
            if key2 in road_moving_object or key2 in human:
                for m_c in range(move_count):
                    move_from = description_dictionary[key][key2]["move_from"]
                    move_to = description_dictionary[key][key2]["move_to"]
                    y_dir = move_to[m_c][0] - move_from[m_c][0]
                    x_dir = move_to[m_c][1] - move_from[m_c][1]

                    all_appear_grids = []

                    for grd in description_dictionary[key][key2]["move_from_grids"]:
                        all_appear_grids += grd

                    unique_appear_grid = list(set(all_appear_grids))

                    if y_dir < 0:
                        y_dir_s = "toward far"
                    elif y_dir > 0:
                        y_dir_s = "closer to"
                    else:
                        y_dir_s = ""

                    if x_dir < 0:
                        x_dir_s = "right"
                    elif x_dir > 0:
                        x_dir_s = "left"
                    else:
                        x_dir_s = ""

                    if x_dir_s and y_dir_s:
                        mid_hi = " "
                    else:
                        mid_hi = ""

                    if x_dir_s or y_dir_s:
                        pos_s = ''

                        if len(unique_appear_grid) >= 5:
                            pos_s = ""
                        elif len(unique_appear_grid) == 1:
                            pos_s = f"The {labels_dicto[key2]['name']} which was at {pos_dict[unique_appear_grid[0]]} moves slightly {y_dir_s}{mid_hi}{x_dir_s}"
                        elif len(unique_appear_grid) == 2:
                            pos_s = f"The {labels_dicto[key2]['name']} which was at {pos_dict[unique_appear_grid[0]]}-{pos_dict[unique_appear_grid[1]]} moves slightly {y_dir_s}{mid_hi}{x_dir_s}"
                        elif len(unique_appear_grid) == 3 or len(unique_appear_grid) == 4:
                            far_count = 0
                            close_count = 0
                            for bb in range(3):
                                if "far" in pos_dict[unique_appear_grid[bb]]:
                                    far_count += 1
                                else:
                                    close_count += 1
                            if far_count == 3:
                                pos_s = f"The {labels_dicto[key2]['name']} from the far front moves slightly {y_dir_s}{mid_hi}{x_dir_s}"
                            elif close_count == 3:
                                pos_s = f"The {labels_dicto[key2]['name']} from near front moves slightly {y_dir_s}{mid_hi}{x_dir_s}"
                            else:
                                left_count = 0
                                right_count = 0
                                center_count = 0
                                for bb in range(3):
                                    if "left" in pos_dict[unique_appear_grid[bb]]:
                                        left_count += 1
                                    elif "right" in pos_dict[unique_appear_grid[bb]]:
                                        right_count += 1
                                    else:
                                        center_count += 1
                                pos_array = ['left', 'center', 'right']
                                pos_ind_ar = [left_count, center_count, right_count]
                                max_pos_ind = pos_ind_ar.index(max(pos_ind_ar))
                                max_pos_n = pos_array[max_pos_ind]
                                if max_pos_n == 'center':
                                    pos_s = f"The {labels_dicto[key2]['name']} ahead of you moves slightly {y_dir_s}{mid_hi}{x_dir_s}"
                                else:
                                    pos_s = f"The {labels_dicto[key2]['name']} from your {max_pos_n} slightly {y_dir_s}{mid_hi}{x_dir_s}"

                        if pos_s:
                            descriptions[key].append(
                                pos_s
                            )


                

        

# for key in description_dictionary.keys():
#     descriptions[key] = []
#     for key2 in description_dictionary[key].keys():
#         appear_count = description_dictionary[key][key2]["appear"]
#         disappear_count = description_dictionary[key][key2]["disappear"]
#         move_count = description_dictionary[key][key2]["move"]
#         if appear_count > 0:
#             add_s = ''
#             if appear_count > 1:
#                 add_s = 's'
                
#             all_appera_grids = []
            
#             for grd in description_dictionary[key][key2]["appear_grids"]:
#                 all_appera_grids += grd
            
#             unique_appear_grid = list(set(all_appera_grids))
            
#             if len(unique_appear_grid) >= 5:
#                 pos_s = "surrounding you"
#             elif len(unique_appear_grid) == 1:
#                 pos_s = f"at {pos_dict[unique_appear_grid[0]]} position"
#             elif len(unique_appear_grid) == 2:
#                 pos_s = f"at {pos_dict[unique_appear_grid[0]]} and {pos_dict[unique_appear_grid[1]]} position"
#             elif len(unique_appear_grid) == 3:
#                 upper_count = 0
#                 mid_count = 0
#                 for bb in range(3):
#                     if "upper" in pos_dict[unique_appear_grid[bb]]:
#                         upper_count += 1
#                     elif "mid" in pos_dict[unique_appear_grid[bb]]:
#                         mid_count += 1
#                 if upper_count == 3:
#                     pos_s = "covering upper portion"
#                 elif mid_count == 3:
#                     pos_s = "covering mid portion"
#                 else:
#                     pos_s = "at both upper and mid portion"
#             else:
#                 pos_s = "at both upper and mid portion"                  
#             descriptions[key].append(
#                 f"{num2words(appear_count).capitalize()} {labels_dicto[key2]['name']}{add_s} appeared in the frame {pos_s}"
#             )
#         if disappear_count > 0:
#             add_s = ''
#             ws_wwr = 'was'
#             if disappear_count > 1:
#                 add_s = 's'
#                 ws_wwr = 'were'
                
#             all_disappera_grids = []
            
#             for grd in description_dictionary[key][key2]["disappear_grids"]:
#                 all_disappera_grids += grd
            
#             unique_disappear_grid = list(set(all_disappera_grids))
            
#             if len(unique_disappear_grid) >= 5:
#                 pos_s = f", which {ws_wwr} surrounding you"
#             elif len(unique_disappear_grid) == 1:
#                 pos_s = f"'s {pos_dict[all_disappera_grids[0]]} position"
#             elif len(unique_disappear_grid) == 2:
#                 pos_s = f"'s {pos_dict[all_disappera_grids[0]]} and {pos_dict[all_disappera_grids[1]]} position"
#             elif len(unique_disappear_grid) == 3:
#                 upper_count = 0
#                 mid_count = 0
#                 for bb in range(3):
#                     if "upper" in pos_dict[all_disappera_grids[bb]]:
#                         upper_count += 1
#                     elif "mid" in pos_dict[all_disappera_grids[bb]]:
#                         mid_count += 1
#                 if upper_count == 3:
#                     pos_s = ", which {ws_wwr} covering upper portion"
#                 elif mid_count == 3:
#                     pos_s = ", which {ws_wwr} covering mid portion"
#                 else:
#                     pos_s = " from both upper and mid portion"
#             else:
#                 pos_s = " from both upper and mid portion"                  
            
#             descriptions[key].append(
#                 f"{num2words(disappear_count).capitalize()} {labels_dicto[key2]['name']}{add_s} disappeared from the frame{pos_s}"
#             )
#         if move_count > 0:
#             for m_c in range(move_count):
#                 move_from = description_dictionary[key][key2]["move_from"]
#                 move_to = description_dictionary[key][key2]["move_to"]
#                 y_dir = move_to[m_c][0] - move_from[m_c][0]
#                 x_dir = move_to[m_c][1] - move_from[m_c][1]
#                 if y_dir < 0:
#                     y_dir_s = "upper"
#                 elif y_dir > 0:
#                     y_dir_s = "bottom"
#                 else:
#                     y_dir_s = ""
                    
#                 if x_dir < 0:
#                     x_dir_s = "right"
#                 elif x_dir > 0:
#                     x_dir_s = "left"
#                 else:
#                     x_dir_s = ""
                    
#                 if x_dir_s and y_dir_s:
#                     mid_hi = "-"
#                 else:
#                     mid_hi = ""
                    
#                 if x_dir_s or y_dir_s:
#                     descriptions[key].append(
#                         f"One {labels_dicto[key2]['name']} moved slightly {y_dir_s}{mid_hi}{x_dir_s} direction"
#                     )
descriptions
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 174/174 [00:00<00:00, 41765.42it/s]
# {0: ['There are some sidewalks near',
#   'A few buildings are at your left',
#   'Beside the left and right sidewalk there are walls',
#   'Beside the left sidewalk a fence comes into view',
#   'Over your far center and center side there are traffic lights on the road',
#   'A few traffic signs are at your left',
#   'There are sky and bunch of trees in the horizon',
#   'Beside the sidewalk there are terrains at your both side',
#   'A few persons are at your left',
#   'On the road a car appears at the left',
#   'On your far right and right side there are buss on the road',
#   'A guard rail appears at the left',
#   'A bridge becomes visible at the left',
#   'A few polegroups are at your left'],
#  28: ['A few buildings are at your left',
#   'A few buildings vanish from your far left and left',
#   'A few walls are ahead of you',
#   'A wall is lost to sight from the left',
#   'Beside the right sidewalk a terrain comes into view',
#   'From near front some terrains recede from view',
#   'Over the far center sidewalk a polegroup becomes visible',
#   'A few polegroups recede from view from your far left and left'],
#  56: ['A building is ahead of you',
#   'Few buildings from your left recede from view',
#   'A few walls are lost to sight from your far center and center',
#   'Beside the left and center sidewalk there are terrains',
#   'A few terrains pass from sight from your left and center',
#   'There are sky and bunch of trees in the horizon',
#   'Over the far left sidewalk a polegroup comes into view'],
#  84: ['At your both side there are buildings',
#   'A building vanishes from sight from ahead of you',
#   'Beside the left sidewalk a terrain becomes visible',
#   'A few polegroups are at your left',
#   'Few polegroups from your left are lost to sight'],
#  112: ['A building appears at the center',
#   'A few buildings are lost to sight from your far center and center',
#   'Beside the left and center sidewalk there are walls',
#   'A wall recedes from view from the left',
#   'Beside the left sidewalk a fence appears',
#   'A person recedes from view from the left',
#   'The person which was at right moves slightly toward far right',
#   'Over the far center and center sidewalk there are polegroups',
#   'A polegroup vanishes from sight from the far left'],
#  140: ['A wall passes from sight from the center',
#   'A few terrains vanish from sight from your left and center',
#   'The person which was at right moves slightly toward far',
#   'On the road a truck becomes visible at the center',
#   'The truck which was at far center-center moves slightly closer to left',
#   'The truck which was at far center-center moves slightly closer to left',
#   'Over the far left sidewalk a polegroup appears'],
#  168: ['A few buildings are ahead of you',
#   'From your both side buildings pass from sight',
#   'A few terrains are at your left',
#   'Few terrains from your right pass from sight',
#   'On the road a car appears at the right',
#   'The car which was at left moves slightly closer to right',
#   'A few trucks are at your left',
#   'A few trucks pass from sight from your far center and center',
#   'The truck which was at center moves slightly closer to left',
#   'A few polegroups are at your left',
#   'From your both side polegroups vanish from sight'],
#  196: ['On your far right and right side there are sidewalks',
#   'From near front some sidewalks pass from sight',
#   'A few terrains are ahead of you',
#   'From your both side terrains vanish',
#   'There are sky and bunch of trees in the horizon',
#   'A guard rail appears at the left'],
#  224: ['There are some buildings far',
#   'From your both side buildings vanish from sight',
#   'There are sky and bunch of trees in the horizon'],
#  252: ['Beside the sidewalk there are terrains at your both side',
#   'From your both side terrains are lost to sight',
#   'On the road a car appears at the far right',
#   'A few cars vanish from your far right and center',
#   'The car which was at right moves slightly closer to right',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups pass from sight'],
#  280: ['On your far center and far right side there are cars on the road',
#   'A car vanishes from sight from the far right',
#   'The car which was at right moves slightly closer to left',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups recede from view'],
#  308: ['A few buildings vanish from sight from your center and right',
#   'Beside the sidewalk there are terrains at your both side',
#   'From your both side terrains are lost to sight',
#   'There are sky and bunch of trees in the horizon'],
#  336: ['At your both side there are sidewalks',
#   'From the far front some sidewalks pass from sight',
#   'A building becomes visible at the left',
#   'A few walls are at your left',
#   'There are sky and bunch of trees in the horizon',
#   'There are some persons far',
#   'A few persons are lost to sight from your far center and far right',
#   'The person which was at far left moves slightly closer to right'],
#  364: ['A sidewalk becomes visible at the left',
#   'Few sidewalks from your left vanish',
#   'Few walls from your right are lost to sight',
#   'Beside the sidewalk there are terrains at your both side',
#   'Few terrains from your left pass from sight',
#   'A few persons are at your left',
#   'A few persons pass from sight from your far left and far center',
#   'The person from the far front moves slightly closer to left',
#   'The person from the far front moves slightly closer to left',
#   'The person from the far front moves slightly closer to right',
#   'The person from the far front moves slightly closer to left',
#   'Few trucks from your left pass from sight',
#   'The truck from the far front moves slightly closer to right',
#   'The truck from the far front moves slightly closer to left',
#   'The truck from the far front moves slightly toward far left',
#   'On your far center and far right side there are buss on the road',
#   'From the far front some buss vanish',
#   'The bus which was at far center moves slightly closer to right'],
#  392: ['There are some terrains far in front of you',
#   'From your both side terrains pass from sight',
#   'There are sky and bunch of trees in the horizon',
#   'A few persons are at your left',
#   'From the far front some persons recede from view',
#   'The person which was at far left-left moves slightly closer to right'],
#  420: ['A sidewalk is lost to sight from the center',
#   'Beside the sidewalk there are terrains at your both side',
#   'From the far front some terrains vanish',
#   'There are sky and bunch of trees in the horizon',
#   'There are some persons far',
#   'Few persons from your left are lost to sight',
#   'The person from your left slightly closer to right',
#   'The person from your left slightly toward far right',
#   'The person from your left slightly closer to left',
#   'A few buss are at your left',
#   'A few buss pass from sight from your far left and far center',
#   'The bus which was at far right-right moves slightly toward far',
#   'A few polegroups are at your left',
#   'Few polegroups from your right vanish'],
#  448: ['At your both side there are buildings',
#   'A few buildings are lost to sight from ahead of you',
#   'There are some persons far',
#   'From your both side persons recede from view',
#   'The person which was at far left-left moves slightly toward far right'],
#  476: ['There are sky and bunch of trees in the horizon',
#   'On your far left and right side there are buss on the road',
#   'A few buss vanish from ahead of you',
#   'The bus which was at far center moves slightly toward far left',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups vanish'],
#  504: ['A few sidewalks are lost to sight from your center and right',
#   'A building vanishes from the right',
#   'Beside the far left sidewalk a terrain appears',
#   'A terrain recedes from view from the far center',
#   'A few buss are at your left',
#   'A few buss recede from view from your far center and right',
#   'The bus which was at far left moves slightly toward far right',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups vanish from sight'],
#  532: ['Beside the sidewalk there are terrains at your both side',
#   'Few terrains from your left vanish from sight',
#   'There are sky and bunch of trees in the horizon',
#   'At your both side there are persons',
#   'From your both side persons pass from sight',
#   'The person ahead of you moves slightly closer to left',
#   'The person ahead of you moves slightly toward far left',
#   'On the road a bus becomes visible at the right',
#   'A few buss recede from view from your far left and right',
#   'The bus which was at far left-far center moves slightly closer to left'],
#  560: ['On your far left and far center side there are buildings',
#   'There are sky and bunch of trees in the horizon',
#   'At your both side there are persons',
#   'From your both side persons pass from sight',
#   'The person which was at far center-center moves slightly toward far'],
#  588: ['There are some buildings far',
#   'A few buildings vanish from sight from your far left and far center',
#   'There are sky and bunch of trees in the horizon'],
#  616: ['From the far front some buildings vanish',
#   'There are sky and bunch of trees in the horizon'],
#  644: ['A building appears at the left',
#   'There are sky and bunch of trees in the horizon'],
#  672: ['A building becomes visible at the right',
#   'A building recedes from view from the left',
#   'Beside the center sidewalk a terrain becomes visible',
#   'A terrain passes from sight from the far center',
#   'On the road a car appears at the far center',
#   'The car which was at far center-center moves slightly toward far left',
#   'On your far center and center side there are buss on the road',
#   'A bus vanishes from sight from the center',
#   'The bus which was at far center moves slightly toward far right',
#   'There are some polegroups far in front of you',
#   'From your both side polegroups vanish'],
#  700: ['A building passes from sight from the right',
#   'There are sky and bunch of trees in the horizon',
#   'A person comes into view at the right',
#   'A few persons are lost to sight from ahead of you',
#   'The person which was at far center-center moves slightly toward far left',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups recede from view'],
#  728: ['A building comes into view at the right',
#   'A few persons are at your right',
#   'A person vanishes from the right',
#   'The person which was at far center-center moves slightly closer to right',
#   'A few polegroups are ahead of you',
#   'A few polegroups vanish from ahead of you'],
#  756: ['A person appears at the far center',
#   'A few persons vanish from sight from your far right and right',
#   'The person which was at far center-center moves slightly closer to left',
#   'The person which was at far center-center moves slightly closer to left',
#   'A few cars are ahead of you',
#   'A car passes from sight from the far center',
#   'The car which was at far center moves slightly closer to right',
#   'The bus which was at far center moves slightly closer to right',
#   'Over the left sidewalk a polegroup appears'],
#  784: ['There are sky and bunch of trees in the horizon',
#   'A few polegroups are ahead of you',
#   'From your both side polegroups pass from sight'],
#  812: ['Over the sidewalk there are polegroups at your both side',
#   'A few polegroups recede from view from ahead of you'],
#  840: ['There are sky and bunch of trees in the horizon'],
#  868: ['Beside the far center and right sidewalk there are walls',
#   'A few walls pass from sight from your far left and right',
#   'A car is at your left',
#   'The car which was at far center moves slightly closer to left',
#   'The car which was at far center moves slightly closer to left',
#   'The bus which was at far center moves slightly left',
#   'Over the sidewalk there are polegroups at your both side',
#   'A few polegroups vanish from sight from ahead of you'],
#  896: ['A few walls vanish from your far center and right',
#   'A few persons are at your left',
#   'The person which was at far center-center moves slightly toward far right',
#   'On your far left and left side there are cars on the road',
#   'The car which was at your left recedes from view',
#   'The car which was at far center-center moves slightly left',
#   'The car which was at far center-center moves slightly left',
#   'The bus which was at far center moves slightly toward far left',
#   'Over the sidewalk there are polegroups at your both side',
#   'Few polegroups from your left vanish'],
#  924: ['Beside the left and right sidewalk there are terrains',
#   'A terrain is lost to sight from the right',
#   'A few persons are at your left',
#   'Few persons from your left recede from view',
#   'The person which was at far center-center moves slightly closer to right',
#   'On your far left and left side there are cars on the road',
#   'A few cars pass from sight from your far left and left',
#   'The car which was at far center-center moves slightly closer to right',
#   'The car which was at far center-center moves slightly closer to left',
#   'On your far left and left side there are buss on the road',
#   'The bus which was at far center moves slightly closer to right',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups are lost to sight'],
#  952: ['Few persons from your left pass from sight',
#   'The person which was at far center-center moves slightly closer to left',
#   'On the road there are cars at your both side',
#   'A few cars pass from sight from your far left and left',
#   'The car which was at far center-center moves slightly closer to left',
#   'The car which was at far center-center moves slightly closer to left',
#   'A few buss are lost to sight from your far left and left',
#   'The bus which was at far center moves slightly closer to left',
#   'A few polegroups are at your left',
#   'Few polegroups from your left pass from sight'],
#  980: ['A building is ahead of you',
#   'A wall is ahead of you',
#   'A few walls recede from view from ahead of you',
#   'On your far center and center side there are persons',
#   'The person which was at far center-center moves slightly closer to right',
#   'On the road a car becomes visible at the left',
#   'From your both side cars recede from view',
#   'The car which was at far center-center moves slightly toward far left',
#   'The car which was at far center-center moves slightly closer to left',
#   'The bus which was at far center-center moves slightly toward far',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  1008: ['A sidewalk is at your left',
#   'A few sidewalks pass from sight from your left and right',
#   'A building vanishes from ahead of you',
#   'On your far center and center side there are persons',
#   'A few persons pass from sight from your far center and center',
#   'The person which was at far center-center moves slightly toward far right',
#   'A car passes from sight from the left',
#   'The car which was at far center-center moves slightly toward far right',
#   'The car which was at far center-center moves slightly closer to right',
#   'A few polegroups are at your left',
#   'From your both side polegroups vanish from sight'],
#  1036: ['A sidewalk is ahead of you',
#   'A sidewalk vanishes from sight from ahead of you',
#   'A building appears at the right',
#   'A few walls recede from view from your far center and center',
#   'Beside the left sidewalk a terrain appears',
#   'A few cars vanish from your far center and center',
#   'The car which was at far center-center moves slightly closer to right'],
#  1064: ['A building becomes visible at the right',
#   'A building passes from sight from the right',
#   'The bus which was at far center moves slightly toward far right',
#   'Over the far left and left sidewalk there are polegroups',
#   'A few polegroups pass from sight from your far left and left'],
#  1092: ['On your center and right side there are buildings',
#   'A few polegroups are at your left',
#   'Few polegroups from your left vanish'],
#  1120: ['A building becomes visible at the left',
#   'A few buildings recede from view from your center and right',
#   'A few polegroups are at your left',
#   'Few polegroups from your left vanish'],
#  1148: ['A sidewalk becomes visible at the center',
#   'A building recedes from view from the left',
#   'There are some persons near',
#   'A person is lost to sight from the center',
#   'The person which was at center moves slightly toward far left',
#   'On your center and right side there are cars on the road',
#   'A few cars vanish from your left and center',
#   'The car which was at left-center moves slightly toward far right',
#   'A few polegroups are ahead of you',
#   'Few polegroups from your left vanish'],
#  1176: ['There are some cars near in front of you',
#   'From near front some cars are lost to sight',
#   'The car which was at center moves slightly closer to right',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  1204: ['Beside the center sidewalk a wall comes into view',
#   'A few walls recede from view from your center and right',
#   'On your left and center side there are cars on the road',
#   'From near front some cars pass from sight',
#   'The car which was at center moves slightly toward far right'],
#  1232: ['A building becomes visible at the far right',
#   'There are sky and bunch of trees in the horizon'],
#  1260: ['A few buildings are ahead of you',
#   'A building passes from sight from the far right',
#   'Beside the sidewalk there are walls at your both side',
#   'A few walls are lost to sight from your far center and far right',
#   'There are sky and bunch of trees in the horizon'],
#  1288: ['A few buildings recede from view from ahead of you',
#   'On your far right and right side there are persons',
#   'Few persons from your left vanish',
#   'The person which was at far left-left moves slightly toward far left'],
#  1316: [],
#  1344: ['A sidewalk vanishes from the right',
#   'A building becomes visible at the right',
#   'A few buildings are lost to sight from your far right and right',
#   'A traffic light vanishes from sight from the far center',
#   'Beside the far left sidewalk a terrain appears',
#   'A person becomes visible at the far center',
#   'A few persons vanish from your far center and center',
#   'The person which was at far center-center moves slightly closer to left',
#   'A car is lost to sight from the far center',
#   'The car which was at far center moves slightly toward far right',
#   'Over the far center and center sidewalk there are polegroups',
#   'A few polegroups vanish from sight from your far center and center'],
#  1372: ['There are sky and bunch of trees in the horizon',
#   'A few polegroups are at your left',
#   'A few polegroups vanish from your far center and center'],
#  1400: ['There are sky and bunch of trees in the horizon',
#   'Over the center sidewalk a polegroup comes into view',
#   'A few polegroups recede from view from your far center and center'],
#  1428: ['A wall recedes from view from the center',
#   'The person which was at center moves slightly toward far left',
#   'Over the far center and center sidewalk there are polegroups',
#   'A polegroup is lost to sight from the center'],
#  1456: ['Beside the center sidewalk a wall becomes visible',
#   'Beside the center sidewalk a terrain comes into view',
#   'There are sky and bunch of trees in the horizon',
#   'The person which was at center moves slightly closer to left'],
#  1484: ['A terrain vanishes from the center',
#   'A person comes into view at the left',
#   'The person which was at center moves slightly closer to left',
#   'Over the far center and center sidewalk there are polegroups',
#   'A few polegroups pass from sight from your far center and center'],
#  1512: ['There are sky and bunch of trees in the horizon'],
#  1540: ['At your both side there are sidewalks',
#   'A sidewalk is lost to sight from the left',
#   'A few walls are ahead of you',
#   'Few walls from your right pass from sight',
#   'A few cars are ahead of you',
#   'A few cars are lost to sight from your far center and far right',
#   'The car which was at far center moves slightly closer to right',
#   'Over the far right and right sidewalk there are polegroups',
#   'From the far front some polegroups vanish from sight'],
#  1568: ['Over the sidewalk there are polegroups at your both side',
#   'A few polegroups vanish from your far center and far right'],
#  1596: ['A few polegroups are ahead of you',
#   'From your both side polegroups vanish'],
#  1624: ['A sidewalk appears at the right',
#   'Beside the far left and left sidewalk there are terrains',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  1652: ['A few terrains pass from sight from your far left and left',
#   'There are sky and bunch of trees in the horizon',
#   'A few polegroups are at your left',
#   'From your both side polegroups recede from view'],
#  1680: [],
#  1708: ['A wall is at your left',
#   'A wall vanishes from sight from the left',
#   'Beside the far left and left sidewalk there are terrains',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish'],
#  1736: ['Beside the left sidewalk a wall comes into view',
#   'The wall which was at your left is lost to sight'],
#  1764: ['There are sky and bunch of trees in the horizon',
#   'On your far center and center side there are cars on the road',
#   'A few cars are lost to sight from your far center and center',
#   'The car which was at far center-center moves slightly toward far right',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups are lost to sight'],
#  1792: ['Beside the left and center sidewalk there are terrains',
#   'A few terrains are lost to sight from ahead of you',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish from sight'],
#  1820: ['Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish from sight'],
#  1848: [],
#  1876: ['A few buildings are ahead of you',
#   'Over the sidewalk there are polegroups at your both side',
#   'A few polegroups recede from view from ahead of you'],
#  1904: ['A building comes into view at the far right',
#   'A few buildings are lost to sight from ahead of you'],
#  1932: ['On your far right and right side there are buildings',
#   'A building recedes from view from the far right',
#   'There are sky and bunch of trees in the horizon'],
#  1960: ['A few buildings recede from view from your far right and right',
#   'The person which was at far left moves slightly closer to right',
#   'On the road a car appears at the far left',
#   'The car which was at far left moves slightly toward far right',
#   'The car which was at far left moves slightly closer to right',
#   'Over the far left sidewalk a polegroup becomes visible',
#   'A polegroup vanishes from sight from the far left'],
#  1988: ['A building appears at the right',
#   'There are sky and bunch of trees in the horizon',
#   'The person which was at far left moves slightly left',
#   'The car which was at far left moves slightly toward far right',
#   'The car which was at far left moves slightly closer to right',
#   'The car which was at far left moves slightly closer to right',
#   'A few polegroups are at your left',
#   'A few polegroups vanish from sight from your far left and right'],
#  2016: ['A building passes from sight from the right',
#   'There are sky and bunch of trees in the horizon',
#   'A few polegroups are at your left',
#   'Few polegroups from your left vanish'],
#  2044: ['Beside the far center sidewalk a wall comes into view',
#   'A wall passes from sight from the far right',
#   'A person appears at the far center',
#   'From the far front some persons pass from sight',
#   'The person which was at far right moves slightly closer to left',
#   'A car passes from sight from the far right',
#   'There are some polegroups far in front of you',
#   'Few polegroups from your left recede from view'],
#  2072: ['A few polegroups are at your right',
#   'From the far front some polegroups are lost to sight'],
#  2100: ['A sidewalk passes from sight from the right',
#   'On your far center and far right side there are cars on the road',
#   'A few cars are lost to sight from your far left and left',
#   'The car which was at far center-far right moves slightly toward far right',
#   'The car which was at far center-far right moves slightly closer to left',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish'],
#  2128: ['At your both side there are sidewalks',
#   'The sidewalk which was at your left recedes from view',
#   'On your far right and right side there are buildings'],
#  2156: ['A few sidewalks pass from sight from your far right and right',
#   'On your far right and right side there are buildings',
#   'A few buildings recede from view from your far right and right',
#   'Beside the sidewalk there are walls at your both side',
#   'A few walls are lost to sight from your far left and far center',
#   'On your far center and far right side there are cars on the road',
#   'Few cars from your left recede from view',
#   'The car which was at far center moves slightly closer to left',
#   'Over the far left and far center sidewalk there are polegroups',
#   'From your both side polegroups vanish'],
#  2184: ['On your far left and left side there are buildings',
#   'A few buildings recede from view from your far right and right',
#   'There are sky and bunch of trees in the horizon',
#   'Over the sidewalk there are polegroups at your both side',
#   'A few polegroups are lost to sight from your far left and far center'],
#  2212: ['On your far left and left side there are buildings',
#   'Beside the sidewalk there are walls at your both side',
#   'From your both side walls vanish from sight',
#   'The car which was at far right moves slightly closer to right',
#   'The truck which was at far right moves slightly closer to right'],
#  2240: ['There are sky and bunch of trees in the horizon'],
#  2268: ['There are sky and bunch of trees in the horizon',
#   'Over the sidewalk there are polegroups at your both side',
#   'Few polegroups from your left pass from sight'],
#  2296: ['A few sidewalks pass from sight from your far right and right',
#   'A building becomes visible at the right',
#   'A few walls are ahead of you',
#   'A few walls pass from sight from your far right and right',
#   'There are sky and bunch of trees in the horizon',
#   'A person passes from sight from the right',
#   'The person which was at right moves slightly toward far left'],
#  2324: ['A sidewalk appears at the center',
#   'A wall is at your left',
#   'From your both side walls pass from sight',
#   'On your far right and right side there are persons',
#   'The person which was at far right-right moves slightly toward far right',
#   'A few cars pass from sight from your far center and center',
#   'The car which was at far right-right moves slightly closer to right',
#   'Over the far center and center sidewalk there are polegroups',
#   'From your both side polegroups pass from sight'],
#  2352: ['There are sky and bunch of trees in the horizon'],
#  2380: ['A building passes from sight from the right',
#   'There are sky and bunch of trees in the horizon'],
#  2408: ['A building comes into view at the left',
#   'There are sky and bunch of trees in the horizon'],
#  2436: ['A building appears at the left',
#   'A building vanishes from sight from the left',
#   'There are sky and bunch of trees in the horizon'],
#  2464: ['There are sky and bunch of trees in the horizon'],
#  2492: ['A few sidewalks are lost to sight from your far center and center',
#   'On your far center and center side there are cars on the road',
#   'From your both side cars vanish',
#   'The car which was at far left moves slightly closer to left'],
#  2520: ['On your center and right side there are sidewalks',
#   'A sidewalk vanishes from sight from ahead of you',
#   'Over your far center and far right side there are traffic lights on the road',
#   'A few traffic lights vanish from sight from your far left and far center',
#   'Over the sidewalk there are polegroups at your both side',
#   'Few polegroups from your left recede from view'],
#  2548: ['There are sky and bunch of trees in the horizon'],
#  2576: ['A few sidewalks are ahead of you',
#   'A few sidewalks vanish from sight from your far center and far right',
#   'A car is ahead of you',
#   'A few cars vanish from sight from ahead of you',
#   'The car which was at far left-far center moves slightly closer to right',
#   'A bus passes from sight from the far center',
#   'The bus which was at far center moves slightly closer to left'],
#  2604: ['There are some sidewalks far',
#   'From your both side sidewalks vanish',
#   'A building appears at the right',
#   'A person becomes visible at the far center',
#   'A person vanishes from sight from the far center',
#   'The person which was at far left moves slightly closer to right',
#   'A car recedes from view from ahead of you',
#   'The car which was at far left-far center moves slightly closer to left',
#   'The bus which was at far center moves slightly closer to left'],
#  2632: ['At your both side there are sidewalks',
#   'A few sidewalks vanish from your far left and far right',
#   'A building vanishes from sight from the right',
#   'There are sky and bunch of trees in the horizon',
#   'On the road a car appears at the far center',
#   'The car which was at far left-far center moves slightly toward far right',
#   'There are some polegroups far in front of you',
#   'From your both side polegroups recede from view'],
#  2660: ['On your far left and left side there are buildings',
#   'There are sky and bunch of trees in the horizon'],
#  2688: ['There are sky and bunch of trees in the horizon'],
#  2716: [],
#  2744: ['A building comes into view at the far left',
#   'There are sky and bunch of trees in the horizon'],
#  2772: ['There are sky and bunch of trees in the horizon'],
#  2800: ['There are sky and bunch of trees in the horizon'],
#  2828: ['On your far center and center side there are buildings',
#   'Few buildings from your left vanish',
#   'There are sky and bunch of trees in the horizon'],
#  2856: ['A few buildings recede from view from your far center and center',
#   'A person comes into view at the right',
#   'A few persons vanish from your far center and center',
#   'The person from your right slightly toward far left',
#   'The person from your right slightly toward far right',
#   'On the road there are cars at your both side',
#   'The car which was at your left is lost to sight',
#   'The car which was at far center moves slightly toward far right'],
#  2884: ['On the road there are cars at your both side',
#   'From your both side cars recede from view',
#   'The car which was at far center moves slightly toward far left'],
#  2912: ['There are sky and bunch of trees in the horizon'],
#  2940: ['There are sky and bunch of trees in the horizon'],
#  2968: ['There are sky and bunch of trees in the horizon'],
#  2996: ['There are sky and bunch of trees in the horizon'],
#  3024: ['A sidewalk is at your left',
#   'A few sidewalks vanish from your far center and center',
#   'A few terrains are ahead of you',
#   'A few cars are ahead of you',
#   'A few cars vanish from sight from your far center and right',
#   'The car from your left slightly toward far right',
#   'Over the sidewalk there are polegroups at your both side',
#   'A few polegroups are lost to sight from ahead of you'],
#  3052: ['Over your far left and far right side there are traffic lights on the road',
#   'A car is ahead of you',
#   'Few cars from your right are lost to sight',
#   'The car which was at far center-center moves slightly closer to left',
#   'The truck which was at far center moves slightly closer to right',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups are lost to sight'],
#  3080: ['On your center and right side there are sidewalks',
#   'A few sidewalks recede from view from your far center and center'],
#  3108: ['A few walls are lost to sight from your center and right',
#   'A few polegroups are at your left',
#   'A few polegroups vanish from sight from your far center and center'],
#  3136: ['There are sky and bunch of trees in the horizon'],
#  3164: ['On your far left and left side there are buildings'],
#  3192: ['A few buildings vanish from your far left and left',
#   'A few walls are ahead of you'],
#  3220: ['On your far center and left side there are buildings'],
#  3248: ['Beside the sidewalk there are walls at your both side',
#   'A few walls are lost to sight from ahead of you',
#   'There are sky and bunch of trees in the horizon'],
#  3276: ['The truck from your left slightly closer to left'],
#  3304: ['A few walls are at your right',
#   'From your both side walls are lost to sight',
#   'There are sky and bunch of trees in the horizon'],
#  3332: ['On your left and center side there are cars on the road',
#   'The car which was at center moves slightly toward far left'],
#  3360: ['Beside the sidewalk there are walls at your both side',
#   'Few walls from your left are lost to sight'],
#  3388: ['There are sky and bunch of trees in the horizon'],
#  3416: ['A few sidewalks are ahead of you',
#   'A few sidewalks vanish from sight from ahead of you',
#   'On your far left and far right side there are buildings',
#   'From the far front some buildings vanish from sight',
#   'Beside the far center and right sidewalk there are walls',
#   'A wall passes from sight from the center',
#   'Beside the far center sidewalk a fence becomes visible',
#   'A fence vanishes from the far center',
#   'Beside the far right sidewalk a terrain comes into view',
#   'The truck which was at far center moves slightly closer to left',
#   'A few polegroups vanish from your far center and center'],
#  3444: ['A few sidewalks are ahead of you',
#   'From near front some sidewalks recede from view',
#   'On your far center and right side there are buildings',
#   'A building passes from sight from the right',
#   'A few walls are ahead of you',
#   'A few walls vanish from sight from ahead of you',
#   'Beside the far left sidewalk a fence becomes visible',
#   'A few fences are lost to sight from your far left and far center',
#   'A terrain recedes from view from the far right',
#   'There are sky and bunch of trees in the horizon',
#   'The truck which was at far center moves slightly closer to left',
#   'Over the far left and far center sidewalk there are polegroups'],
#  3472: ['At your both side there are sidewalks',
#   'A few sidewalks pass from sight from ahead of you',
#   'There are sky and bunch of trees in the horizon'],
#  3500: ['Beside the far right and right sidewalk there are walls',
#   'A few walls recede from view from your far right and right',
#   'Beside the far right sidewalk a fence becomes visible',
#   'There are sky and bunch of trees in the horizon'],
#  3528: ['Few buildings from your right vanish from sight',
#   'There are sky and bunch of trees in the horizon'],
#  3556: ['A sidewalk recedes from view from the right',
#   'Beside the left sidewalk a wall appears',
#   'A few walls vanish from sight from your far right and right',
#   'There are sky and bunch of trees in the horizon'],
#  3584: ['A terrain vanishes from the far left',
#   'There are sky and bunch of trees in the horizon'],
#  3612: ['On your far right and right side there are buildings',
#   'Beside the far right sidewalk a fence becomes visible',
#   'There are sky and bunch of trees in the horizon',
#   'The truck which was at far right-right moves slightly toward far right',
#   'A few polegroups are at your left',
#   'From the far front some polegroups vanish from sight'],
#  3640: ['A few sidewalks pass from sight from your left and center',
#   'A building comes into view at the right',
#   'A few buildings are lost to sight from your far right and right',
#   'Beside the far right sidewalk a fence becomes visible',
#   'A fence vanishes from sight from the far right',
#   'There are sky and bunch of trees in the horizon',
#   'The truck which was at far right-right moves slightly closer to right'],
#  3668: [],
#  3696: ['Beside the left sidewalk a wall comes into view',
#   'A few walls vanish from your left and center',
#   'A few fences are at your right',
#   'A few fences recede from view from your far left and right',
#   'On your far left and center side there are bridges',
#   'Few bridges from your left pass from sight',
#   'A polegroup is ahead of you',
#   'From your both side polegroups vanish'],
#  3724: ['From the far front some buildings are lost to sight'],
#  3752: ['On your left and right side there are sidewalks',
#   'A few sidewalks vanish from sight from your far center and right',
#   'A wall vanishes from the far left',
#   'A few fences are at your right',
#   'From the far front some fences vanish from sight'],
#  3780: ['On your far center and right side there are buildings',
#   'Beside the far center and center sidewalk there are terrains',
#   'A terrain is lost to sight from the left'],
#  3808: ['On your far right and right side there are buildings',
#   'A building passes from sight from the far center',
#   'Beside the far center and center sidewalk there are walls',
#   'A few walls recede from view from ahead of you',
#   'A few fences are at your left',
#   'A few fences are lost to sight from your far center and far right',
#   'A few polegroups are at your left',
#   'From your both side polegroups recede from view'],
#  3836: ['On your far right and right side there are buildings',
#   'A few buildings are lost to sight from your far right and right',
#   'Beside the far right and right sidewalk there are fences',
#   'Few fences from your left are lost to sight',
#   'Beside the far right and left sidewalk there are terrains',
#   'A few terrains pass from sight from ahead of you',
#   'At your both side there are persons',
#   'A few persons vanish from your far center and center',
#   'The person which was at far left-left moves slightly closer to right',
#   'A few cars are at your right',
#   'A few cars pass from sight from ahead of you',
#   'The car ahead of you moves slightly toward far right',
#   'On your far center and far right side there are bridges',
#   'A few bridges vanish from your far right and right'],
#  3864: ['On your far center and far right side there are buildings',
#   'A few buildings vanish from your far right and right',
#   'Beside the far center and far right sidewalk there are terrains',
#   'From your both side terrains recede from view',
#   'Over the sidewalk there are polegroups at your both side',
#   'A few polegroups recede from view from ahead of you'],
#  3892: ['A building appears at the far center',
#   'A few buildings are lost to sight from your far center and far right',
#   'Beside the far right and right sidewalk there are terrains',
#   'A few terrains vanish from your far right and left',
#   'A few cars are at your left',
#   'Few cars from your left are lost to sight',
#   'The car which was at center moves slightly toward far left',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish'],
#  3920: ['At your both side there are sidewalks',
#   'A few sidewalks vanish from sight from your far left and left',
#   'A few buildings are ahead of you',
#   'A few walls are at your right',
#   'Few walls from your right pass from sight',
#   'There are sky and bunch of trees in the horizon',
#   'On your far center and center side there are persons',
#   'The person which was at far center-center moves slightly closer to left',
#   'A few cars vanish from sight from your left and center',
#   'The car which was at far left-far center moves slightly closer to right',
#   'The car which was at far left-far center moves slightly left',
#   'The car which was at far left-far center moves slightly closer to left',
#   'The bus which was at far left moves slightly toward far right',
#   'A few bridges recede from view from ahead of you',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  3948: ['A building vanishes from sight from the far center',
#   'Beside the far center and right sidewalk there are walls',
#   'Few walls from your right vanish from sight',
#   'There are sky and bunch of trees in the horizon',
#   'On your far left and far center side there are cars on the road',
#   'A few cars vanish from your far left and far center',
#   'The car which was at far left-far center moves slightly toward far right',
#   'The car which was at far left-far center moves slightly toward far right',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  3976: ['On your far left and left side there are sidewalks',
#   'From your both side sidewalks vanish',
#   'A building appears at the far center',
#   'Beside the far left sidewalk a wall appears',
#   'A few walls are lost to sight from your far center and right',
#   'There are sky and bunch of trees in the horizon',
#   'On your far center and center side there are persons',
#   'A few persons recede from view from your center and right',
#   'The person which was at far center moves slightly closer to right',
#   'A few cars are at your right',
#   'The car which was at far left-far center moves slightly closer to right',
#   'The car which was at far left-far center moves slightly closer to right',
#   'The car which was at far left-far center moves slightly closer to right',
#   'The car which was at far left-far center moves slightly closer to right',
#   'On the road a bus appears at the far left',
#   'The bus which was at far left moves slightly closer to right',
#   'On your far center and far right side there are bridges',
#   'There are some polegroups far in front of you',
#   'From your both side polegroups vanish'],
#  4004: ['There are some buildings far',
#   'From the far front some buildings recede from view',
#   'A few terrains are at your left',
#   'A few terrains vanish from sight from your far center and far right',
#   'There are sky and bunch of trees in the horizon',
#   'On your far left and far right side there are persons',
#   'A few persons vanish from sight from your far center and center',
#   'The person which was at far center moves slightly closer to right',
#   'A few cars are at your left',
#   'Few cars from your right pass from sight',
#   'The car from your left slightly toward far right',
#   'The car from your left slightly closer to right',
#   'The car from your left slightly closer to right',
#   'The car from your left slightly closer to left',
#   'On your far center and far right side there are bridges',
#   'A few bridges are lost to sight from your far center and far right',
#   'There are some polegroups far in front of you',
#   'A few polegroups pass from sight from ahead of you'],
#  4032: ['There are some buildings far',
#   'From the far front some buildings vanish',
#   'Beside the far center and far right sidewalk there are walls',
#   'A few walls are lost to sight from your far center and far right',
#   'A few terrains are at your right',
#   'A few terrains vanish from sight from your far center and far right',
#   'There are sky and bunch of trees in the horizon',
#   'A person comes into view at the far right',
#   'A few persons recede from view from your far left and far right',
#   'The person which was at far center-center moves slightly toward far right',
#   'On your far left and left side there are cars on the road',
#   'Few cars from your left are lost to sight',
#   'The car from the far front moves slightly closer to right',
#   'The car from the far front moves slightly toward far left',
#   'The car from the far front moves slightly closer to left',
#   'A few bridges pass from sight from your far center and far right',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups recede from view'],
#  4060: ['There are sky and bunch of trees in the horizon'],
#  4088: ['There are some buildings far',
#   'From near front some buildings are lost to sight',
#   'There are sky and bunch of trees in the horizon',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups recede from view'],
#  4116: ['At your both side there are buildings',
#   'From the far front some buildings are lost to sight',
#   'There are some terrains far in front of you',
#   'Few terrains from your left vanish from sight',
#   'There are sky and bunch of trees in the horizon',
#   'Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups pass from sight'],
#  4144: ['Over the sidewalk there are polegroups at your both side',
#   'From your both side polegroups vanish from sight'],
#  4172: ['A person appears at the far left',
#   'A person vanishes from sight from the far left',
#   'The person which was at far left moves slightly closer to right'],
#  4200: ['There are sky and bunch of trees in the horizon'],
#  4228: ['There are some walls far in front of you',
#   'A few walls recede from view from your far left and far center',
#   'Beside the far right and center sidewalk there are terrains',
#   'Few terrains from your right vanish from sight',
#   'There are sky and bunch of trees in the horizon'],
#  4256: ['A sidewalk is lost to sight from the left',
#   'There are some walls far in front of you',
#   'A few walls are lost to sight from your far center and far right',
#   'Beside the far right sidewalk a terrain appears',
#   'A few terrains pass from sight from your far right and center',
#   'There are sky and bunch of trees in the horizon'],
#  4284: ['There are some walls far in front of you',
#   'From the far front some walls pass from sight',
#   'A terrain vanishes from the far right',
#   'A person vanishes from the far center',
#   'The person which was at far center moves slightly toward far left',
#   'Over the far left and center sidewalk there are polegroups',
#   'A polegroup vanishes from the left'],
#  4312: ['There are sky and bunch of trees in the horizon'],
#  4340: ['A few buildings pass from sight from your far left and left',
#   'A few terrains are at your right',
#   'A few terrains are lost to sight from your far left and far right',
#   'There are sky and bunch of trees in the horizon'],
#  4368: ['A few sidewalks are at your left',
#   'A sidewalk recedes from view from the far left',
#   'There are sky and bunch of trees in the horizon',
#   'There are some cars far in front of you',
#   'From the far front some cars vanish',
#   'The car which was at far left moves slightly closer to left',
#   'There are some polegroups far in front of you',
#   'A few polegroups vanish from sight from your far center and far right'],
#  4396: ['There are some buildings far',
#   'There are sky and bunch of trees in the horizon'],
#  4424: ['There are sky and bunch of trees in the horizon'],
#  4452: ['There are sky and bunch of trees in the horizon',
#   'On your far left and far center side there are cars on the road',
#   'A few cars are lost to sight from your far left and far center',
#   'The car which was at far center-far right moves slightly closer to left'],
#  4480: ['A building passes from sight from the far right',
#   'Beside the far center sidewalk a wall becomes visible',
#   'A few walls pass from sight from your far center and far right',
#   'There are some cars far in front of you',
#   'From the far front some cars are lost to sight',
#   'The car which was at far center moves slightly closer to right',
#   'On your far center and far right side there are buss on the road',
#   'A few buss vanish from your far center and far right',
#   'The bus which was at right moves slightly closer to right'],
#  4508: ['There are sky and bunch of trees in the horizon',
#   'There are some polegroups far in front of you',
#   'From the far front some polegroups vanish'],
#  4536: ['On your far left and left side there are buildings',
#   'There are sky and bunch of trees in the horizon'],
#  4564: ['A few buildings recede from view from your far left and left',
#   'Beside the far left sidewalk a terrain appears',
#   'A terrain recedes from view from the center',
#   'There are sky and bunch of trees in the horizon'],
#  4592: ['A building appears at the left',
#   'There are sky and bunch of trees in the horizon'],
#  4620: ['A building vanishes from sight from the left',
#   'There are sky and bunch of trees in the horizon'],
#  4648: ['A few buildings are at your right',
#   'There are sky and bunch of trees in the horizon'],
#  4676: ['There are sky and bunch of trees in the horizon'],
#  4704: ['There are sky and bunch of trees in the horizon'],
#  4732: ['There are sky and bunch of trees in the horizon',
#   'The bicycle which was at center moves slightly toward far right'],
#  4760: ['A few buildings are at your right',
#   'A building vanishes from the far center',
#   'There are sky and bunch of trees in the horizon'],
#  4788: ['There are sky and bunch of trees in the horizon'],
#  4816: ['On your far left and far center side there are sidewalks',
#   'A few sidewalks pass from sight from your far left and far center',
#   'There are sky and bunch of trees in the horizon',
#   'On your far right and right side there are persons',
#   'The person which was at left-center moves slightly toward far left',
#   'The truck which was at center moves slightly toward far',
#   'The bus which was at far left moves slightly toward far right',
#   'The bus which was at far left moves slightly left'],
#  4844: ['The person from your left slightly left',
#   'The person from your left slightly closer to left',
#   'The truck which was at center moves slightly right',
#   'On the road a bus becomes visible at the right',
#   'The bus which was at far left moves slightly closer to left']}

# %%
write_lines = []
subs = []
sec = 0
ind = 1
for key in descriptions.keys():
    start = timedelta(seconds=sec)
    end = timedelta(seconds=sec+des_every_sec)
    sec_des = ", ".join(descriptions[key])    
    subs.append(Subtitle(index=ind, start=start, end=end, content=sec_des))
    ind += 1
    sec += des_every_sec
                         
with open('/Users/imrankabir/Downloads/video_for_app/gameplay_video_1/descriptions.srt', 'w') as f:
    f.write(compose(subs))
