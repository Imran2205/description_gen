# %%
import numpy as np
import cv2
from copy import deepcopy
import os
from PIL import Image
import matplotlib.pyplot as plt
import math

# %%
class ObjVar:
    def __init__(self, position, bbox, grids, class_name, area):
        self.position = position
        self.bbox = bbox
        self.grids = grids
        self.class_name = class_name
        self.area = area
        

class ObjDetector(object):
    def __init__(self):
        self.labels_dict = {
        0:  {'name': 'unlabeled',      'color': (0,   0,   0),   'ct_scape_id': 0,  'train_id': 255},
        1:  {'name': 'road',           'color': (128, 64,  128), 'ct_scape_id': 7,  'train_id': 1},
        2:  {'name': 'sidewalk',       'color': (244, 35,  232), 'ct_scape_id': 8,  'train_id': 2},
        3:  {'name': 'building',       'color': (70,  70,  70),  'ct_scape_id': 11, 'train_id': 3},
        4:  {'name': 'wall',           'color': (102, 102, 156), 'ct_scape_id': 12, 'train_id': 4},
        5:  {'name': 'fence',          'color': (190, 153, 153), 'ct_scape_id': 13, 'train_id': 5},
        6:  {'name': 'pole',           'color': (153, 153, 153), 'ct_scape_id': 17, 'train_id': 6},
        7:  {'name': 'traffic light',   'color': (250, 170, 30),  'ct_scape_id': 19, 'train_id': 7},
        8:  {'name': 'traffic sign',    'color': (220, 220, 0),   'ct_scape_id': 20, 'train_id': 8},
        9:  {'name': 'vegetation',     'color': (107, 142, 35),  'ct_scape_id': 21, 'train_id': 9},
        10: {'name': 'terrain',        'color': (152, 251, 152), 'ct_scape_id': 22, 'train_id': 10},
        11: {'name': 'sky',            'color': (70,  130, 180), 'ct_scape_id': 23, 'train_id': 11},
        12: {'name': 'person',         'color': (220, 20,  60),  'ct_scape_id': 24, 'train_id': 12},
        13: {'name': 'rider',          'color': (255, 0,   0),   'ct_scape_id': 25, 'train_id': 13},
        14: {'name': 'car',            'color': (0,   0,   142), 'ct_scape_id': 26, 'train_id': 14},
        15: {'name': 'truck',          'color': (0,   0,   70),  'ct_scape_id': 27, 'train_id': 15},
        16: {'name': 'bus',            'color': (0,   60,  100), 'ct_scape_id': 28, 'train_id': 16},
        17: {'name': 'train',          'color': (0,   80,  100), 'ct_scape_id': 31, 'train_id': 17},
        18: {'name': 'motorcycle',     'color': (0,   0,   230), 'ct_scape_id': 32, 'train_id': 18},
        19: {'name': 'bicycle',        'color': (119, 11,  32),  'ct_scape_id': 33, 'train_id': 19},
        20: {'name': 'dynamic',        'color': (111, 74,  0),   'ct_scape_id': 5,  'train_id': 20},
        21: {'name': 'ground',         'color': (81,  0,   81),  'ct_scape_id': 6,  'train_id': 21},
        22: {'name': 'parking',        'color': (250, 170, 160), 'ct_scape_id': 9,  'train_id': 22},
        23: {'name': 'rail track',     'color': (230, 150, 140), 'ct_scape_id': 10, 'train_id': 23},
        24: {'name': 'guard rail',     'color': (180, 165, 180), 'ct_scape_id': 14, 'train_id': 24},
        25: {'name': 'bridge',         'color': (150, 100, 100), 'ct_scape_id': 15, 'train_id': 25},
        26: {'name': 'tunnel',         'color': (150, 120, 90),  'ct_scape_id': 16, 'train_id': 26},
        27: {'name': 'polegroup',      'color': (153, 153, 153), 'ct_scape_id': 18, 'train_id': 27},
        28: {'name': 'caravan',        'color': (0,   0,   90),  'ct_scape_id': 29, 'train_id': 28},
        29: {'name': 'trailer',        'color': (0,   0,   110), 'ct_scape_id': 30, 'train_id': 29}
    }
        
    def get_grid_span(self, x, y, w, h, h_g_l, v_g_l):
        g_x = []
        g_y = []
        
        i = 1
        while not (x >= h_g_l[i - 1] and x < h_g_l[i]):
            i += 1
        g_x.append(i)

        while not (x+w >= h_g_l[i - 1] and x+w < h_g_l[i]):
            i += 1  
        if not i in g_x:
            g_x.append(i)
        if len(g_x) > 1:
            for ii in range(g_x[0]+1, g_x[1]):
                g_x.append(ii)
                
        g_x.sort()
        
        j = 1
        while not (y >= v_g_l[j - 1] and y < v_g_l[j]):
            j += 1 
        g_y.append(j)

        while not (y+h >= v_g_l[j - 1] and y+h < v_g_l[j]):
            j += 1  
        if not j in g_y:
            g_y.append(j)
        if len(g_y) > 1:
            for jj in range(g_y[0]+1, g_y[1]):
                g_y.append(jj)      
        g_y.sort()
            
        final_g = []
        for x in g_x:
            for y in g_y:
                final_g.append((y-1)*3 + x)
                
        return final_g

    
    def get_localization(self, img_lbl, detect_obj=[], grid_count=3):
        obj_dict = {}
        for key in self.labels_dict.keys():
            obj_id = self.labels_dict[key]['train_id']
            temp_img = deepcopy(img_lbl)
            temp_img[temp_img != obj_id] = 0
            temp_img[temp_img == obj_id] = 255
            
            temp_img = cv2.GaussianBlur(temp_img, (25, 25), 0)
            temp_img = cv2.dilate(temp_img, np.ones((20, 20), np.uint8), iterations=1)
            temp_img = cv2.erode(temp_img, np.ones((10, 10), np.uint8), iterations=1)

            th = int(np.max(temp_img) * 0.15)
            temp_img[temp_img > th] = 255
            temp_img[temp_img <= th] = 0
            
            contours, hierarchy = cv2.findContours(
                temp_img.astype(np.uint8), 
                cv2.RETR_EXTERNAL, 
                cv2.CHAIN_APPROX_SIMPLE
            )
            
            horizontal_grid_lines = [(i) * (img_lbl.shape[1] // 3) for i in range(grid_count + 1)]
            vertical_grid_lines =  [(i) * (img_lbl.shape[0] // 3) for i in range(grid_count + 1)]
            
            horizontal_grid_lines[-1] = horizontal_grid_lines[-1] + 1
            vertical_grid_lines[-1] = vertical_grid_lines[-1] + 1
       
            for cnt in contours:
                area = cv2.contourArea(cnt)
                if area < 500:
                    continue

                x,y,w,h = cv2.boundingRect(cnt)
                
                if x >= img_lbl.shape[1]:
                    x = x - 1
                
                if x+w >= img_lbl.shape[1]:
                    w = w - 1
                
                if y >= img_lbl.shape[0]:
                    y = y - 1
                
                if y+h >= img_lbl.shape[0]:
                    h = h - 1 

                if h>20 and w>20:
                    if key not in obj_dict.keys():
                        obj_dict[key] = []
                        
                    grids = self.get_grid_span(x, y, w, h, horizontal_grid_lines, vertical_grid_lines)
                    if 7 in grids or 8 in grids or 9 in grids:
                        continue
                        
                    cur_obj = ObjVar(
                        position=[(y + (h//2)), (x + (w//2))],
                        bbox=[y, x, y+h, x+w],
                        grids=grids,
                        class_name=self.labels_dict[key]['name'],
                        area=area
                    )
                    
                    obj_dict[key].append(cur_obj)
                    
            if key not in obj_dict.keys():
                obj_dict[key] = []

        return obj_dict

# %%
def box_iou(a, b): 
    w_intersection = np.maximum (0, (np.minimum(a[2], b[2]) - np.maximum(a[0], b[0])))
    h_intersection = np.maximum (0, (np.minimum(a[3], b[3]) - np.maximum(a[1], b[1])))
    s_intersection = w_intersection * h_intersection
    s_a = (a[2] - a[0])*(a[3] - a[1])
    s_b = (b[2] - b[0])*(b[3] - b[1])
  
    return float(s_intersection)/(s_a + s_b - s_intersection)

# %%
image_dir = os.path.join(os.getcwd(), '../des_gen_img')

source_images = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if '.png' in img]
source_images.sort()

# %%
ignores = [0, 1, 10, 11, 20, 21]
movings = [12, 13, 14, 15, 16, 17, 18, 19, 28, 29]
statics = [2, 3, 4, 5, 6, 7, 8 , 9, 22, 23, 24, 25, 26, 27]
dist_th = 50
iou_th = 0.25

description_dictionary = {}
old_obj_dict = None

for i in range(len(source_images)):
    img = np.asarray(Image.open(source_images[i]))

    obj_detector = ObjDetector()
    new_obj_dict = obj_detector.get_localization(img_lbl=img)
    
    description_dictionary[i] = {}
    
    if old_obj_dict:
        for k in range(30):
            description_dictionary[i][k] = {
                "appear": 0,
                "appear_grids": [],
                "disappear": 0,
                "disappear_grids": [],
                "move": 0,
                "move_from": [],
                "move_to": []
            }
                
            if k in ignores:
                pass
            elif k in movings or k in statics:
                connections = []
                for no, new_obj in enumerate(new_obj_dict[k]):
                    new_pos = new_obj.position
                    new_bbox = new_obj.bbox
                    new_grid = new_obj.grids
                    for oo, old_obj in enumerate(old_obj_dict[k]):
                        old_pos = old_obj.position
                        old_bbox = old_obj.bbox
                        old_grid = old_obj.grids
                        distance = math.dist(new_pos, old_pos)
                        iou = box_iou(new_bbox, old_bbox)
                        if iou > iou_th and distance < dist_th:
                            connections.append(np.array([oo, no])) 
                
                if connections:
                    connections = np.array(connections)
                    for oo in range(len(old_obj_dict[k])):
                        if oo not in connections[:, 0]:
                            description_dictionary[i][k]["disappear"] += 1
                            description_dictionary[i][k]["disappear_grids"].append(old_obj_dict[k][oo].grids) 
                        else:
                            description_dictionary[i][k]["move"] += 1
                            frm_ind = connections[np.argwhere(connections[:, 0] == oo)[0][0]]
                            description_dictionary[i][k]["move_from"].append(old_obj_dict[k][frm_ind[0]].position)
                            description_dictionary[i][k]["move_to"].append(new_obj_dict[k][frm_ind[1]].position)

                    for no in range(len(new_obj_dict[k])):
                        if no not in connections[:, 1]:
                            description_dictionary[i][k]["appear"] += 1
                            description_dictionary[i][k]["appear_grids"].append(new_obj_dict[k][no].grids) 
                            
    else:
        for k in range(30):
            description_dictionary[i][k] = {
                "appear": 0,
                "appear_grids": [],
                "disappear": 0,
                "disappear_grids": [],
                "move": 0,
                "move_from": [],
                "move_to": []
            }
            for no in range(len(new_obj_dict[k])):
                description_dictionary[i][k]["appear"] += 1
                description_dictionary[i][k]["appear_grids"].append(new_obj_dict[k][no].grids) 

    old_obj_dict = new_obj_dict
                        
description_dictionary
# Out:
# {0: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 2,
#    'appear_grids': [[4], [5, 6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   3: {'appear': 3,
#    'appear_grids': [[1, 4], [1, 4, 2, 5, 3, 6], [1, 4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   4: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 5,
#    'appear_grids': [[3, 6], [2, 5], [2, 5], [2, 5], [1, 4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   10: {'appear': 2,
#    'appear_grids': [[2, 5], [2, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 1,
#    'appear_grids': [[1, 4, 2, 5, 3, 6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 5,
#    'appear_grids': [[6], [4], [5], [4], [3, 6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 4,
#    'appear_grids': [[5], [4], [5], [4, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   15: {'appear': 1,
#    'appear_grids': [[4, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   16: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 3,
#    'appear_grids': [[4], [4], [6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 6,
#    'appear_grids': [[4], [2, 5, 3, 6], [1, 4], [1], [3, 6], [1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  1: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 2,
#    'appear_grids': [[5], [5]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 1,
#    'move_from': [[268, 837]],
#    'move_to': [[257, 878]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[1, 4]],
#    'move': 2,
#    'move_from': [[135, 595], [120, 73]],
#    'move_to': [[176, 568], [120, 32]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[244, 116]],
#    'move_to': [[250, 104]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 4,
#    'appear_grids': [[4], [3, 6], [2, 5], [2, 5]],
#    'disappear': 4,
#    'disappear_grids': [[3, 6], [2, 5], [2, 5], [2, 5]],
#    'move': 1,
#    'move_from': [[159, 143]],
#    'move_to': [[133, 105]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   15: {'appear': 2,
#    'appear_grids': [[5], [5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[234, 299]],
#    'move_to': [[233, 315]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 3,
#    'appear_grids': [[1, 4], [1], [3, 6]],
#    'disappear': 5,
#    'disappear_grids': [[4], [2, 5, 3, 6], [1, 4], [1], [1]],
#    'move': 1,
#    'move_from': [[169, 750]],
#    'move_to': [[182, 766]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  2: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 2,
#    'appear_grids': [[4], [5]],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 2,
#    'move_from': [[245, 641], [257, 878]],
#    'move_to': [[245, 626], [257, 911]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   4: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[250, 104]],
#    'move_to': [[253, 102]]},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 3,
#    'appear_grids': [[4, 5], [3, 6], [2, 5, 3, 6]],
#    'disappear': 3,
#    'disappear_grids': [[4], [3, 6], [2, 5]],
#    'move': 2,
#    'move_from': [[172, 553], [133, 105]],
#    'move_to': [[167, 555], [142, 116]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[233, 479]],
#    'move_to': [[227, 490]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  3: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 5,
#    'appear_grids': [[6], [4], [4], [6], [5, 6]],
#    'disappear': 3,
#    'disappear_grids': [[4], [6], [5]],
#    'move': 1,
#    'move_from': [[250, 414]],
#    'move_to': [[245, 397]]},
#   3: {'appear': 1,
#    'appear_grids': [[1, 4, 2, 5, 3, 6]],
#    'disappear': 3,
#    'disappear_grids': [[1, 4], [1, 4, 2, 5], [2, 5, 3, 6]],
#    'move': 1,
#    'move_from': [[151, 155]],
#    'move_to': [[140, 151]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 4,
#    'appear_grids': [[4], [1, 4], [3], [2]],
#    'disappear': 3,
#    'disappear_grids': [[4, 5], [2, 5, 3, 6], [1, 4]],
#    'move': 2,
#    'move_from': [[182, 931], [167, 555]],
#    'move_to': [[171, 974], [189, 571]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[227, 490]],
#    'move_to': [[231, 480]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 2,
#    'appear_grids': [[4], [3, 6]],
#    'disappear': 2,
#    'disappear_grids': [[4], [5, 6]],
#    'move': 1,
#    'move_from': [[235, 579]],
#    'move_to': [[226, 590]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  4: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 5,
#    'appear_grids': [[4], [2, 5], [2, 5], [2, 3], [2, 5]],
#    'disappear': 4,
#    'disappear_grids': [[1, 4], [2, 5, 3, 6], [3], [2]],
#    'move': 2,
#    'move_from': [[222, 155], [171, 974]],
#    'move_to': [[230, 173], [164, 943]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   15: {'appear': 2,
#    'appear_grids': [[6], [6]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 1,
#    'move_from': [[189, 747]],
#    'move_to': [[193, 719]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  5: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   3: {'appear': 2,
#    'appear_grids': [[6], [3, 6]],
#    'disappear': 1,
#    'disappear_grids': [[3, 6]],
#    'move': 1,
#    'move_from': [[214, 366]],
#    'move_to': [[219, 360]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 4,
#    'appear_grids': [[4, 5], [5, 6], [6], [3, 6]],
#    'disappear': 3,
#    'disappear_grids': [[4], [2, 5], [3]],
#    'move': 4,
#    'move_from': [[230, 173], [199, 438], [117, 663], [159, 572]],
#    'move_to': [[235, 139], [209, 458], [126, 677], [164, 582]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 2,
#    'appear_grids': [[6], [6]],
#    'disappear': 2,
#    'disappear_grids': [[4], [3, 6]],
#    'move': 1,
#    'move_from': [[239, 525]],
#    'move_to': [[248, 528]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 5,
#    'appear_grids': [[5], [5], [2, 5], [3], [2]],
#    'disappear': 1,
#    'disappear_grids': [[2]],
#    'move': 1,
#    'move_from': [[170, 378]],
#    'move_to': [[157, 356]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  6: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[260, 416]],
#    'move_to': [[250, 396]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 3,
#    'appear_grids': [[5], [1, 4], [2]],
#    'disappear': 1,
#    'disappear_grids': [[2]],
#    'move': 1,
#    'move_from': [[197, 273]],
#    'move_to': [[188, 280]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   9: {'appear': 3,
#    'appear_grids': [[4, 5], [1, 4], [1]],
#    'disappear': 4,
#    'disappear_grids': [[4, 5], [6], [1, 4], [3, 6]],
#    'move': 4,
#    'move_from': [[268, 675], [209, 458], [126, 677], [164, 582]],
#    'move_to': [[248, 687], [192, 429], [123, 695], [130, 598]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 2,
#    'appear_grids': [[4], [6]],
#    'disappear': 2,
#    'disappear_grids': [[6], [6]],
#    'move': 1,
#    'move_from': [[248, 528]],
#    'move_to': [[236, 539]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[187, 840]],
#    'move_to': [[165, 870]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 5,
#    'disappear_grids': [[5], [5], [2, 5], [3], [2]],
#    'move': 1,
#    'move_from': [[157, 356]],
#    'move_to': [[135, 312]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  7: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 3,
#    'appear_grids': [[6], [5, 6], [6]],
#    'disappear': 3,
#    'disappear_grids': [[5], [5, 6], [5]],
#    'move': 1,
#    'move_from': [[279, 138]],
#    'move_to': [[272, 113]]},
#   3: {'appear': 4,
#    'appear_grids': [[2], [2, 5, 3, 6], [3], [1, 2]],
#    'disappear': 2,
#    'disappear_grids': [[2, 5], [2, 5, 3, 6]],
#    'move': 2,
#    'move_from': [[238, 447], [197, 205]],
#    'move_to': [[243, 447], [191, 210]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 1,
#    'move_from': [[250, 396]],
#    'move_to': [[250, 403]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[217, 401]],
#    'move_to': [[220, 399]]},
#   9: {'appear': 2,
#    'appear_grids': [[4], [2]],
#    'disappear': 3,
#    'disappear_grids': [[4, 5], [2, 5], [1]],
#    'move': 4,
#    'move_from': [[248, 687], [211, 95], [192, 429], [123, 695]],
#    'move_to': [[242, 701], [209, 86], [189, 395], [112, 712]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 2,
#    'disappear_grids': [[4], [6]],
#    'move': 1,
#    'move_from': [[236, 539]],
#    'move_to': [[233, 556]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[165, 870]],
#    'move_to': [[146, 910]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 4,
#    'appear_grids': [[5], [5], [2, 5, 3, 6], [2, 5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[135, 312]],
#    'move_to': [[136, 320]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  8: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 2,
#    'appear_grids': [[6], [5]],
#    'disappear': 3,
#    'disappear_grids': [[6], [5, 6], [6]],
#    'move': 1,
#    'move_from': [[272, 113]],
#    'move_to': [[285, 111]]},
#   3: {'appear': 2,
#    'appear_grids': [[2, 5, 3, 6], [2, 5, 3, 6]],
#    'disappear': 4,
#    'disappear_grids': [[5], [2], [2, 5, 3, 6], [3]],
#    'move': 2,
#    'move_from': [[191, 210], [12, 200]],
#    'move_to': [[204, 231], [18, 162]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[250, 403], [248, 731]],
#    'move_to': [[259, 410], [260, 746]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 2,
#    'appear_grids': [[1, 4], [1]],
#    'disappear': 2,
#    'disappear_grids': [[1, 4], [1]],
#    'move': 1,
#    'move_from': [[30, 386]],
#    'move_to': [[22, 367]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[220, 399]],
#    'move_to': [[222, 388]]},
#   9: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 5,
#    'move_from': [[242, 701], [209, 86], [189, 395], [112, 712], [79, 592]],
#    'move_to': [[256, 724], [221, 69], [198, 390], [118, 719], [75, 593]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[233, 556]],
#    'move_to': [[244, 572]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[146, 910]],
#    'move_to': [[154, 949]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 3,
#    'appear_grids': [[5], [1, 4], [1, 4]],
#    'disappear': 3,
#    'disappear_grids': [[5], [5], [1, 4, 2, 5]],
#    'move': 2,
#    'move_from': [[233, 691], [168, 655]],
#    'move_to': [[237, 700], [157, 661]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  9: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 2,
#    'appear_grids': [[6], [6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[280, 928], [285, 111], [274, 427]],
#    'move_to': [[289, 945], [292, 104], [280, 436]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[2, 5, 3, 6]],
#    'move': 3,
#    'move_from': [[204, 231], [149, 816], [18, 162]],
#    'move_to': [[211, 232], [153, 786], [17, 156]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 2,
#    'move_from': [[259, 410], [260, 746]],
#    'move_to': [[269, 408], [261, 732]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 1,
#    'appear_grids': [[1]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[186, 248], [165, 174], [22, 367]],
#    'move_to': [[190, 242], [168, 183], [22, 359]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[222, 388]],
#    'move_to': [[240, 388]]},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 6,
#    'move_from': [[270, 173],
#     [256, 724],
#     [221, 69],
#     [198, 390],
#     [118, 719],
#     [75, 593]],
#    'move_to': [[278, 173],
#     [258, 701],
#     [226, 55],
#     [204, 387],
#     [119, 719],
#     [79, 592]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[244, 572]],
#    'move_to': [[248, 568]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   16: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[176, 556]],
#    'move_to': [[184, 539]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 2,
#    'disappear_grids': [[5], [6]],
#    'move': 3,
#    'move_from': [[180, 232], [157, 661], [143, 133]],
#    'move_to': [[179, 217], [168, 659], [148, 122]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  10: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 1,
#    'appear_grids': [[1, 4]],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 4,
#    'move_from': [[289, 945], [292, 104], [280, 436], [254, 772]],
#    'move_to': [[294, 949], [299, 103], [286, 440], [257, 774]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[211, 232], [153, 786], [17, 156]],
#    'move_to': [[217, 239], [155, 783], [16, 202]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 2,
#    'move_from': [[269, 408], [261, 732]],
#    'move_to': [[269, 400], [271, 724]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[1]],
#    'move': 3,
#    'move_from': [[190, 242], [168, 183], [22, 359]],
#    'move_to': [[196, 242], [175, 163], [25, 360]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[240, 388]],
#    'move_to': [[247, 395]]},
#   9: {'appear': 2,
#    'appear_grids': [[6], [1, 2]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 6,
#    'move_from': [[278, 173],
#     [258, 701],
#     [226, 55],
#     [204, 387],
#     [119, 719],
#     [79, 592]],
#    'move_to': [[283, 172],
#     [268, 695],
#     [233, 55],
#     [210, 363],
#     [124, 718],
#     [90, 591]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[280, 140]],
#    'move_to': [[279, 153]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
# ...
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[257, 388], [190, 206], [157, 63]],
#    'move_to': [[260, 388], [188, 206], [156, 63]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  15: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 2,
#    'disappear_grids': [[6], [6]],
#    'move': 4,
#    'move_from': [[325, 1001], [306, 67], [301, 193], [287, 405]],
#    'move_to': [[323, 1000], [305, 62], [300, 193], [286, 368]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 2,
#    'disappear_grids': [[2], [2, 3]],
#    'move': 3,
#    'move_from': [[219, 227], [190, 863], [21, 232]],
#    'move_to': [[219, 227], [189, 873], [20, 226]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[306, 938], [291, 777]],
#    'move_to': [[302, 938], [301, 774]]},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[189, 219], [173, 152], [150, 39]],
#    'move_to': [[189, 219], [173, 152], [149, 41]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[233, 380]],
#    'move_to': [[231, 383]]},
#   9: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 1,
#    'disappear_grids': [[1]],
#    'move': 3,
#    'move_from': [[209, 244], [110, 730], [63, 594]],
#    'move_to': [[209, 255], [110, 730], [63, 594]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 1,
#    'appear_grids': [[3, 6]],
#    'disappear': 2,
#    'disappear_grids': [[6], [4]],
#    'move': 1,
#    'move_from': [[323, 952]],
#    'move_to': [[321, 951]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[251, 599]],
#    'move_to': [[250, 599]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 1,
#    'move_from': [[211, 662]],
#    'move_to': [[245, 655]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[236, 566]],
#    'move_to': [[235, 578]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[329, 680]],
#    'move_to': [[327, 680]]},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[260, 388], [188, 206], [156, 63]],
#    'move_to': [[250, 387], [187, 206], [156, 55]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  16: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 1,
#    'appear_grids': [[4]],
#    'disappear': 2,
#    'disappear_grids': [[4], [6]],
#    'move': 3,
#    'move_from': [[323, 1000], [305, 62], [286, 368]],
#    'move_to': [[323, 1002], [305, 61], [286, 396]]},
#   3: {'appear': 1,
#    'appear_grids': [[2]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[219, 227], [189, 873], [20, 226]],
#    'move_to': [[220, 227], [189, 838], [18, 228]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[189, 219], [173, 152], [149, 41]],
#    'move_to': [[189, 219], [172, 152], [150, 40]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[231, 383]],
#    'move_to': [[230, 383]]},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[6]],
#    'move': 3,
#    'move_from': [[209, 255], [110, 730], [63, 594]],
#    'move_to': [[208, 256], [110, 730], [62, 594]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[321, 951], [169, 1012]],
#    'move_to': [[322, 951], [170, 1011]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   15: {'appear': 1,
#    'appear_grids': [[5]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[245, 655]],
#    'move_to': [[238, 654]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[235, 578]],
#    'move_to': [[234, 572]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[327, 680]],
#    'move_to': [[327, 680]]},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[347, 692]],
#    'move_to': [[346, 691]]},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[250, 387], [187, 206], [156, 55]],
#    'move_to': [[254, 387], [186, 204], [155, 58]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}},
#  17: {0: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   1: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   2: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 1,
#    'disappear_grids': [[4]],
#    'move': 3,
#    'move_from': [[323, 1002], [305, 61], [286, 396]],
#    'move_to': [[323, 1002], [305, 61], [286, 362]]},
#   3: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[2]],
#    'move': 3,
#    'move_from': [[220, 227], [189, 838], [18, 228]],
#    'move_to': [[219, 228], [189, 838], [19, 223]]},
#   4: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   5: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   6: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   7: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[189, 219], [172, 152], [150, 40]],
#    'move_to': [[189, 219], [172, 152], [149, 40]]},
#   8: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[230, 383]],
#    'move_to': [[230, 383]]},
#   9: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[208, 256], [110, 730], [62, 594]],
#    'move_to': [[208, 255], [110, 730], [62, 594]]},
#   10: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   11: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   12: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[322, 951], [170, 1011]],
#    'move_to': [[321, 952], [170, 1011]]},
#   13: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   14: {'appear': 1,
#    'appear_grids': [[6]],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 2,
#    'move_from': [[308, 596], [170, 690]],
#    'move_to': [[310, 615], [166, 691]]},
#   15: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 1,
#    'disappear_grids': [[5]],
#    'move': 1,
#    'move_from': [[238, 654]],
#    'move_to': [[240, 700]]},
#   16: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[234, 572]],
#    'move_to': [[234, 570]]},
#   17: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   18: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 1,
#    'move_from': [[346, 691]],
#    'move_to': [[343, 689]]},
#   19: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   20: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   21: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   22: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   23: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   24: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   25: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   26: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   27: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 3,
#    'move_from': [[254, 387], [186, 204], [155, 58]],
#    'move_to': [[251, 387], [186, 204], [155, 58]]},
#   28: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []},
#   29: {'appear': 0,
#    'appear_grids': [],
#    'disappear': 0,
#    'disappear_grids': [],
#    'move': 0,
#    'move_from': [],
#    'move_to': []}}}

# %%
descriptions = {}
labels_dicto = ObjDetector().labels_dict
for key in description_dictionary.keys():
    description[key] = []
    for key2 in description_dictionary[key].keys():
        appear_count = description_dictionary[key][key2]["appear"]
        disappear_count = description_dictionary[key][key2]["disappear"]
        if appear_count > 0:
            add_s = ''
            if appear_count > 1:
                add_s = 's'
            description[key].append(
                f"{appear_count} {labels_dicto[key2]}{add_s} appeared in the frame"
            )
        if disappear_count > 0:
            add_s = ''
            if disappear_count > 1:
                add_s = 's'
            description[key].append(
                f"{disappear_count} {labels_dicto[key2]}{add_s} disappeared from the frame"
            )
